# %%
import numpy as np

# %% [markdown]
# # Eig

# %%
np.linalg.eig(np.random.rand(500, 500));

# %%
np.linalg.eig(np.random.rand(1000, 1000));

# %%
np.linalg.eig(np.random.rand(2000, 2000));

# %%
np.linalg.eig(np.random.rand(3000, 3000));

# %%
np.linalg.eig(np.random.rand(4000, 4000));

# %%
np.linalg.eig(np.random.rand(5000, 5000));

# %% [markdown]
# # Svd

# %%
np.linalg.svd(np.random.rand(500, 500));

# %%
np.linalg.svd(np.random.rand(1000, 1000));

# %%
np.linalg.svd(np.random.rand(2000, 2000));

# %%
np.linalg.svd(np.random.rand(3000, 3000));

# %%
np.linalg.svd(np.random.rand(4000, 4000));

# %%
np.linalg.svd(np.random.rand(5000, 5000));
