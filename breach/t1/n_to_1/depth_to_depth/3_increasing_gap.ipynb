# %% [markdown]
# **Constantes**
#
# Tamanho da sequência utilizada, tamanho da janela, frequência de _cutoff_, tamanho de lote, etc.

# %%
BASE_VALUE = 'depth'
BATCH_SIZE = 32
CUTOFF_FREQUENCY = 0.009
DATA_FOLDER = '../../data'
DENSE_ACTIVATION_FUNCTION = 'linear'
EARLY_STOP_EPOCH = 66
EARLY_STOP_PATIENCE = 36
EPOCHS = 200
INITIAL_LEARNING_RATE = 0.001
LEARNING_RATE_REDUCER_FACTOR = 0.5
LEARNING_RATE_REDUCER_PATIENCE = 16
LSTM_COUNT = [8]
NORMALIZE = True
NOTEBOOK_NAME = '3_increasing_gap'
PREDICTED_VALUE = 'depth'
SAMPLE_RATE = 1
SEQUENCE_GAP = 4
SEQUENCE_SIZE = 12
TEST_SPLIT_FACTOR = 3

# %%
PLOT_TITLE = f'{BASE_VALUE} -> {PREDICTED_VALUE}'

# %%
from keras.callbacks import ReduceLROnPlateau
from tensorflow.python.platform import tf_logging as logging


class ReduceLRBacktrack(ReduceLROnPlateau):
    def __init__(self, best_path, *args, **kwargs):
        super(ReduceLRBacktrack, self).__init__(*args, **kwargs)
        self.best_path = best_path

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.monitor)
        if current is None:
            logging.warning('Reduce LR on plateau conditioned on metric `%s` '
                            'which is not available. Available metrics are: %s',
                            self.monitor, ','.join(list(logs.keys())))
        if not self.monitor_op(current, self.best):  # not new best
            if not self.in_cooldown():  # and we're not in cooldown
                if self.wait+1 >= self.patience:  # going to reduce lr
                    # load best model so far
                    print("Backtracking to best model before reducting LR")
                    self.model.load_weights(self.best_path)

        super().on_epoch_end(epoch, logs)  # actually reduce LR
# Out:
# 2023-10-27 16:25:33.125425: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-27 16:25:33.155820: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 16:25:33.155847: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 16:25:33.155865: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-27 16:25:33.160842: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-27 16:25:33.161449: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-27 16:25:34.024311: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Estado para reproduzir os mesmos resultados

# %%
from keras.utils import set_random_seed

set_random_seed(42)

# %% [markdown]
# # Preparação dos dados
#
# Carregando os arquivos .csv que contém os dados de altura da lâmina e vazão.

# %% [markdown]
# ## Altura

# %%
import pandas as pd

# %%
depth_df = pd.read_csv(f'{DATA_FOLDER}/water_depth_reservoir_Test1.csv')
display(depth_df)
# Out:
#       time (s)  water depth (m)  Unnamed: 2
# 0            0          0.45045         NaN
# 1            1          0.45070         NaN
# 2            2          0.45086         NaN
# 3            3          0.45096         NaN
# 4            4          0.45100         NaN
# ...        ...              ...         ...
# 4313      4313          0.43703         NaN
# 4314      4314          0.43711         NaN
# 4315      4315          0.43720         NaN
# 4316      4316          0.43729         NaN
# 4317      4317          0.43737         NaN
#
# [4318 rows x 3 columns]

# %% [markdown]
# Devido à forma como o CSV está organizado, há uma coluna extra indesejada.
#
# Para corrigir isso, podemos dropar essa coluna utilizando pandas.

# %%
depth_df = depth_df.drop(columns=[depth_df.columns[-1]])
display(depth_df)
# Out:
#       time (s)  water depth (m)
# 0            0          0.45045
# 1            1          0.45070
# 2            2          0.45086
# 3            3          0.45096
# 4            4          0.45100
# ...        ...              ...
# 4313      4313          0.43703
# 4314      4314          0.43711
# 4315      4315          0.43720
# 4316      4316          0.43729
# 4317      4317          0.43737
#
# [4318 rows x 2 columns]

# %% [markdown]
# Ignorando coluna com o valor do tempo, pois a coluna de índice é equivalente.

# %%
depth_df = depth_df.drop(columns=[depth_df.columns[0]])
display(depth_df)
# Out:
#       water depth (m)
# 0             0.45045
# 1             0.45070
# 2             0.45086
# 3             0.45096
# 4             0.45100
# ...               ...
# 4313          0.43703
# 4314          0.43711
# 4315          0.43720
# 4316          0.43729
# 4317          0.43737
#
# [4318 rows x 1 columns]

# %% [markdown]
# ## Vazão

# %%
discharge_df = pd.read_csv(f'{DATA_FOLDER}/discharge_inlet_Test1.csv')
display(discharge_df)
# Out:
#       time (s)  inlet discharge (m3/s)
# 0            1                0.000630
# 1            1                0.000388
# 2            1                0.000203
# 3            1                0.000070
# 4            4               -0.000020
# ...        ...                     ...
# 4313      4313                0.024713
# 4314      4314                0.024809
# 4315      4315                0.024889
# 4316      4316                0.024951
# 4317      4317                0.024999
#
# [4318 rows x 2 columns]

# %% [markdown]
# Na coluna indicando o tempo em segundos, o valor "1" está sendo repetido 4 vezes.
#
# Tendo em vista que os valores da vazão mudaram para essas 4 entradas, vamos assumir que isso foi um erro de registro e que os valores são na realidade 0, 1, 2, ...
#
# Essa mudança torna esse dataset consistente com o de altura carregado anteriormente.
#
# Da mesma forma como fizemos anteriormente, podemos tratar a coluna de índices como nosso indicador de tempo.

# %%
discharge_df = discharge_df.drop(columns=[discharge_df.columns[0]])
display(discharge_df)
# Out:
#       inlet discharge (m3/s)
# 0                   0.000630
# 1                   0.000388
# 2                   0.000203
# 3                   0.000070
# 4                  -0.000020
# ...                      ...
# 4313                0.024713
# 4314                0.024809
# 4315                0.024889
# 4316                0.024951
# 4317                0.024999
#
# [4318 rows x 1 columns]

# %% [markdown]
# Podemos unir os dados em um só DF, o que facilita a preparação dos mesmos

# %%
unified_df = pd.concat([discharge_df, depth_df], axis=1)
display(unified_df)
# Out:
#       inlet discharge (m3/s)  water depth (m)
# 0                   0.000630          0.45045
# 1                   0.000388          0.45070
# 2                   0.000203          0.45086
# 3                   0.000070          0.45096
# 4                  -0.000020          0.45100
# ...                      ...              ...
# 4313                0.024713          0.43703
# 4314                0.024809          0.43711
# 4315                0.024889          0.43720
# 4316                0.024951          0.43729
# 4317                0.024999          0.43737
#
# [4318 rows x 2 columns]

# %% [markdown]
# ## Remoção de ruídos

# %%
from scipy.signal import butter, filtfilt

smoothed_df = unified_df.copy()

original_discharge = smoothed_df['inlet discharge (m3/s)'].values
b, a = butter(N=6, Wn=CUTOFF_FREQUENCY/(0.5*SAMPLE_RATE), btype='low')
y = filtfilt(b, a, original_discharge)
smoothed_df['inlet discharge (m3/s)'] = y

original_depth = smoothed_df['water depth (m)'].values
b, a = butter(N=6, Wn=CUTOFF_FREQUENCY/(0.5*SAMPLE_RATE), btype='low')
y = filtfilt(b, a, original_depth)
smoothed_df['water depth (m)'] = y

# %% [markdown]
# Verificando resultado da remoção de ruído

# %%
import matplotlib.pyplot as plt

plt.plot(unified_df['inlet discharge (m3/s)'])
plt.plot(smoothed_df['inlet discharge (m3/s)'])
plt.show()

plt.plot(unified_df['inlet discharge (m3/s)'].values[:2000])
plt.plot(smoothed_df['inlet discharge (m3/s)'].values[:2000])
plt.show()

plt.plot(unified_df['water depth (m)'])
plt.plot(smoothed_df['water depth (m)'])
plt.show()

plt.plot(unified_df['water depth (m)'].values[:2000])
plt.plot(smoothed_df['water depth (m)'].values[:2000])
plt.show()

# %% [markdown]
# Convertendo o DataFrame em array numpy para facilitar acesso.

# %%
unified = smoothed_df.to_numpy()

# %% [markdown]
# ## Normalização

# %%
from sklearn.preprocessing import MinMaxScaler

unified_scaler = MinMaxScaler()
water_depth_scaler = MinMaxScaler()
inlet_discharge_scaler = MinMaxScaler()
water_depth_scaler.fit(unified[:, 1].reshape(-1, 1))
inlet_discharge_scaler.fit(unified[:, 0].reshape(-1, 1))
unified_scaler.fit(unified)
# Out:
# MinMaxScaler()

# %%
if NORMALIZE:
    if PREDICTED_VALUE == 'depth':
        OUTPUT_SCALER = water_depth_scaler
    elif PREDICTED_VALUE == 'discharge':
        OUTPUT_SCALER = inlet_discharge_scaler
    elif PREDICTED_VALUE == 'both':
        OUTPUT_SCALER = unified_scaler
    else:
        raise ValueError(f'PREDICTED_VALUE must be one of [depth, discharge, both], got {PREDICTED_VALUE}')
    unified = unified_scaler.transform(unified)

# %% [markdown]
# ## Estrutura dos dados de treinamento

# %%
# Obtendo índices lower..upper
i = 0
lower = list()
upper = list()
while i + SEQUENCE_SIZE < len(unified):
    lower.append(i)
    upper.append(i + SEQUENCE_SIZE)
    print(f"[{i}, {i + SEQUENCE_SIZE})")
    i += SEQUENCE_GAP
# Out:
# [0, 12)
# [4, 16)
# [8, 20)
# [12, 24)
# [16, 28)
# [20, 32)
# [24, 36)
# [28, 40)
# [32, 44)
# [36, 48)
# [40, 52)
# [44, 56)
# [48, 60)
# [52, 64)
# [56, 68)
# [60, 72)
# [64, 76)
# [68, 80)
# [72, 84)
# [76, 88)
# [80, 92)
# [84, 96)
# [88, 100)
# [92, 104)
# [96, 108)
# [100, 112)
# [104, 116)
# [108, 120)
# [112, 124)
# [116, 128)
# [120, 132)
# [124, 136)
# [128, 140)
# [132, 144)
# [136, 148)
# [140, 152)
# [144, 156)
# [148, 160)
# [152, 164)
# [156, 168)
# [160, 172)
# [164, 176)
# [168, 180)
# [172, 184)
# [176, 188)
# [180, 192)
# [184, 196)
# [188, 200)
# [192, 204)
# [196, 208)
# [200, 212)
# [204, 216)
# [208, 220)
# [212, 224)
# [216, 228)
# [220, 232)
# [224, 236)
# [228, 240)
# [232, 244)
# [236, 248)
# [240, 252)
# [244, 256)
# [248, 260)
# [252, 264)
# [3980, 3992)
# [3984, 3996)
# [3988, 4000)
# [3992, 4004)
# [3996, 4008)
# [4000, 4012)
# [4004, 4016)
# [4008, 4020)
# [4012, 4024)
# [4016, 4028)
# [4020, 4032)
# [4024, 4036)
# [4028, 4040)
# [4032, 4044)
# [4036, 4048)
# [4040, 4052)
# [4044, 4056)
# [4048, 4060)
# [4052, 4064)
# [4056, 4068)
# [4060, 4072)
# [4064, 4076)
# [4068, 4080)
# [4072, 4084)
# [4076, 4088)
# [4080, 4092)
# [4084, 4096)
# [4088, 4100)
# [4092, 4104)
# [4096, 4108)
# [4100, 4112)
# [4104, 4116)
# [4108, 4120)
# [4112, 4124)
# [4116, 4128)
# [4120, 4132)
# [4124, 4136)
# [4128, 4140)
# [4132, 4144)
# [4136, 4148)
# [4140, 4152)
# [4144, 4156)
# [4148, 4160)
# [4152, 4164)
# [4156, 4168)
# [4160, 4172)
# [4164, 4176)
# [4168, 4180)
# [4172, 4184)
# [4176, 4188)
# [4180, 4192)
# [4184, 4196)
# [4188, 4200)
# [4192, 4204)
# [4196, 4208)
# [4200, 4212)
# [4204, 4216)
# [4208, 4220)
# [4212, 4224)
# [4216, 4228)
# [4220, 4232)
# [4224, 4236)
# [4228, 4240)
# [4232, 4244)
# [4236, 4248)
# [4240, 4252)
# [4244, 4256)
# [4248, 4260)
# [4252, 4264)
# [4256, 4268)
# [4260, 4272)
# [4264, 4276)
# [4268, 4280)
# [4272, 4284)
# [4276, 4288)
# [4280, 4292)
# [4284, 4296)
# [4288, 4300)
# [4292, 4304)
# [4296, 4308)
# [4300, 4312)
# [4304, 4316)

# %% [markdown]
# Construindo sequência de inputs e outputs utilizadas pela rede.
#
# No caso desse notebook:
#
# - Input: Altura da lâmina
# - Output: Altura da lâmina

# %%
import numpy as np

number_of_sequences = len(lower)
display("Quantidade de sequências", number_of_sequences)

TRAINING_SIZE = int(number_of_sequences * (1 - 1 / TEST_SPLIT_FACTOR))
display("Quantidade de sequências de treinamento", TRAINING_SIZE)

inputs = np.zeros((number_of_sequences, SEQUENCE_SIZE, 1))
if PREDICTED_VALUE == 'both':
    outputs = np.zeros((number_of_sequences, SEQUENCE_SIZE, 2))
elif PREDICTED_VALUE == 'depth' or PREDICTED_VALUE == 'discharge':
    outputs = np.zeros((number_of_sequences, 1))
else:
    raise ValueError(f'PREDICTED_VALUE must be one of [depth, discharge, both], got {PREDICTED_VALUE}')
for i in range(number_of_sequences):
    if BASE_VALUE == 'depth':
        inputs[i, :] = unified[lower[i]:upper[i], 1].reshape(-1, 1)
    elif BASE_VALUE == 'discharge':
        inputs[i, :] = unified[lower[i]:upper[i], 0].reshape(-1, 1)
    elif BASE_VALUE == 'both':
        inputs[i, :] = unified[lower[i]:upper[i], :]
    else:
        raise ValueError(f'BASE_VALUE must be one of [depth, discharge, both], got {BASE_VALUE}')
    if PREDICTED_VALUE == 'both':
        outputs[i, :] = unified[upper[i], :]
    elif PREDICTED_VALUE == 'depth':
        outputs[i, :] = unified[upper[i], 1]
    elif PREDICTED_VALUE == 'discharge':
        outputs[i, :] = unified[upper[i], 0]
    else:
        raise ValueError(f'PREDICTED_VALUE must be one of [depth, discharge, both], got {PREDICTED_VALUE}')

inputs_train = inputs[:TRAINING_SIZE]
outputs_train = outputs[:TRAINING_SIZE]
inputs_test = inputs[TRAINING_SIZE:]
outputs_test = outputs[TRAINING_SIZE:]
display("Shapes", inputs_train.shape, outputs_train.shape,
        inputs_test.shape, outputs_test.shape)
# Out:
# 'Quantidade de sequências'
# 1077
# 'Quantidade de sequências de treinamento'
# 718
# 'Shapes'
# (718, 12, 1)
# (718, 1)
# (359, 12, 1)
# (359, 1)

# %% [markdown]
# # Rede neural e treinamento (Adam)

# %%
from keras.models import Sequential
from keras.layers import LSTM, InputLayer, Dense
from keras.optimizers import Adam
from keras.utils import plot_model
import os

if os.path.exists(f'{NOTEBOOK_NAME}/model.png'):
    os.remove(f'{NOTEBOOK_NAME}/model.png')

model = Sequential(name=NOTEBOOK_NAME)
model.add(InputLayer(input_shape=((None, 1)), name='input_layer'))
for i, cell in enumerate(LSTM_COUNT[:-1]):
    model.add(LSTM(cell, return_sequences=True, name=f'lstm_layer_{i + 1}'))
model.add(LSTM(LSTM_COUNT[-1], name=f'lstm_layer_{len(LSTM_COUNT)}'))
model.add(Dense(1, DENSE_ACTIVATION_FUNCTION, name=DENSE_ACTIVATION_FUNCTION))
model.summary()
opt = Adam(learning_rate=INITIAL_LEARNING_RATE, amsgrad=True)

if not os.path.exists(NOTEBOOK_NAME):
    os.mkdir(NOTEBOOK_NAME)
plot_model(model, f'{NOTEBOOK_NAME}/model.png', show_shapes=True)
model.compile(loss='mae', optimizer=opt)
# Out:
# Model: "3_increasing_gap"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_layer_1 (LSTM)         (None, 8)                 320
#
#  linear (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 329 (1.29 KB)
# Trainable params: 329 (1.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-10-27 16:25:36.033558: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-27 16:25:36.033940: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

history = model.fit(
    inputs_train, outputs_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    shuffle=True,
    validation_batch_size=BATCH_SIZE//2,
    validation_split=0.15,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=EARLY_STOP_PATIENCE,
                      verbose=1, restore_best_weights=True, start_from_epoch=EARLY_STOP_EPOCH),
        ModelCheckpoint(f'{NOTEBOOK_NAME}/model_adam.h5',
                        save_best_only=True, save_weights_only=True),
        ReduceLRBacktrack(f'{NOTEBOOK_NAME}/model_adam.h5',
                          monitor='val_loss', patience=LEARNING_RATE_REDUCER_PATIENCE, factor=LEARNING_RATE_REDUCER_FACTOR, verbose=1)
    ]
)
# Recuperando melhor modelo
model.load_weights(f'{NOTEBOOK_NAME}/model_adam.h5')
# Out:
# Epoch 1/200
# 20/20 [==============================] - 2s 23ms/step - loss: 0.5403 - val_loss: 0.2649 - lr: 0.0010
# Epoch 2/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2556 - val_loss: 0.1127 - lr: 0.0010
# Epoch 3/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0534 - val_loss: 0.1351 - lr: 0.0010
# Epoch 4/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0372 - val_loss: 0.1317 - lr: 0.0010
# Epoch 5/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0351 - val_loss: 0.1230 - lr: 0.0010
# Epoch 6/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0331 - val_loss: 0.1178 - lr: 0.0010
# Epoch 7/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0314 - val_loss: 0.1129 - lr: 0.0010
# Epoch 8/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0303 - val_loss: 0.1025 - lr: 0.0010
# Epoch 9/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0284 - val_loss: 0.1003 - lr: 0.0010
# Epoch 10/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0277 - val_loss: 0.0934 - lr: 0.0010
# Epoch 11/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0260 - val_loss: 0.0859 - lr: 0.0010
# Epoch 12/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0243 - val_loss: 0.0768 - lr: 0.0010
# Epoch 13/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0222 - val_loss: 0.0714 - lr: 0.0010
# Epoch 14/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0199 - val_loss: 0.0668 - lr: 0.0010
# Epoch 15/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0189 - val_loss: 0.0570 - lr: 0.0010
# Epoch 16/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0161 - val_loss: 0.0471 - lr: 0.0010
# Epoch 17/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0143 - val_loss: 0.0404 - lr: 0.0010
# Epoch 18/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0119 - val_loss: 0.0303 - lr: 0.0010
# Epoch 19/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.0235 - lr: 0.0010
# Epoch 20/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0164 - lr: 0.0010
# Epoch 21/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0129 - lr: 0.0010
# Epoch 22/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0127 - lr: 0.0010
# Epoch 23/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0173 - lr: 0.0010
# Epoch 24/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0168 - lr: 0.0010
# Epoch 25/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0146 - lr: 0.0010
# Epoch 26/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0187 - lr: 0.0010
# Epoch 27/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0142 - lr: 0.0010
# Epoch 28/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0153 - lr: 0.0010
# Epoch 29/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0164 - lr: 0.0010
# Epoch 30/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0153 - lr: 0.0010
# Epoch 31/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0178 - lr: 0.0010
# Epoch 32/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0146 - lr: 0.0010
# Epoch 33/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0161 - lr: 0.0010
# Epoch 34/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0164 - lr: 0.0010
# Epoch 35/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0142 - lr: 0.0010
# Epoch 36/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0152 - lr: 0.0010
# Epoch 37/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0154 - lr: 0.0010
# Epoch 38/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0053Backtracking to best model before reducting LR
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0132 - lr: 0.0010
# Epoch 39/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0144 - lr: 5.0000e-04
# Epoch 40/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0156 - lr: 5.0000e-04
# Epoch 41/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0146 - lr: 5.0000e-04
# Epoch 42/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0148 - lr: 5.0000e-04
# Epoch 43/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0154 - lr: 5.0000e-04
# Epoch 44/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0153 - lr: 5.0000e-04
# Epoch 45/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0160 - lr: 5.0000e-04
# Epoch 46/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0166 - lr: 5.0000e-04
# Epoch 47/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0169 - lr: 5.0000e-04
# Epoch 48/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0165 - lr: 5.0000e-04
# Epoch 49/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0151 - lr: 5.0000e-04
# Epoch 50/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0152 - lr: 5.0000e-04
# Epoch 51/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0167 - lr: 5.0000e-04
# Epoch 52/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0164 - lr: 5.0000e-04
# Epoch 53/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0146 - lr: 5.0000e-04
# Epoch 54/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0054Backtracking to best model before reducting LR
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0146 - lr: 5.0000e-04
# Epoch 55/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0135 - lr: 2.5000e-04
# Epoch 56/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0134 - lr: 2.5000e-04
# Epoch 57/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0142 - lr: 2.5000e-04
# Epoch 58/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0148 - lr: 2.5000e-04
# Epoch 59/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0141 - lr: 2.5000e-04
# Epoch 60/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0149 - lr: 2.5000e-04
# Epoch 61/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0156 - lr: 2.5000e-04
# Epoch 62/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0148 - lr: 2.5000e-04
# Epoch 63/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0152 - lr: 2.5000e-04
# Epoch 64/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0155 - lr: 2.5000e-04
# Epoch 65/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0159 - lr: 2.5000e-04
# Epoch 66/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0162 - lr: 2.5000e-04
# Epoch 67/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0152 - lr: 2.5000e-04
# Epoch 68/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0161 - lr: 2.5000e-04
# Epoch 69/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0162 - lr: 2.5000e-04
# Epoch 70/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0054Backtracking to best model before reducting LR
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0160 - lr: 2.5000e-04
# Epoch 71/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0132 - lr: 1.2500e-04
# Epoch 72/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0136 - lr: 1.2500e-04
# Epoch 73/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0139 - lr: 1.2500e-04
# Epoch 74/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0139 - lr: 1.2500e-04
# Epoch 75/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0145 - lr: 1.2500e-04
# Epoch 76/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0141 - lr: 1.2500e-04
# Epoch 77/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0141 - lr: 1.2500e-04
# Epoch 78/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0145 - lr: 1.2500e-04
# Epoch 79/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0145 - lr: 1.2500e-04
# Epoch 80/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0147 - lr: 1.2500e-04
# Epoch 81/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0148 - lr: 1.2500e-04
# Epoch 82/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0151 - lr: 1.2500e-04
# Epoch 83/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0145 - lr: 1.2500e-04
# Epoch 84/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0156 - lr: 1.2500e-04
# Epoch 85/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0154 - lr: 1.2500e-04
# Epoch 86/200
# 19/20 [===========================>..] - ETA: 0s - loss: 0.0052Backtracking to best model before reducting LR
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0153 - lr: 1.2500e-04
# Epoch 87/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0136 - lr: 6.2500e-05
# Epoch 88/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0137 - lr: 6.2500e-05
# Epoch 89/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0134 - lr: 6.2500e-05
# Epoch 90/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0138 - lr: 6.2500e-05
# Epoch 91/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0135 - lr: 6.2500e-05
# Epoch 92/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0141 - lr: 6.2500e-05
# Epoch 93/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0142 - lr: 6.2500e-05
# Epoch 94/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0139 - lr: 6.2500e-05
# Epoch 95/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0143 - lr: 6.2500e-05
# Epoch 96/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0145 - lr: 6.2500e-05
# Epoch 97/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0144 - lr: 6.2500e-05
# Epoch 98/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0141 - lr: 6.2500e-05
# Epoch 99/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0143 - lr: 6.2500e-05
# Epoch 100/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0142 - lr: 6.2500e-05
# Epoch 101/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0145 - lr: 6.2500e-05
# Epoch 102/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0056Backtracking to best model before reducting LR
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0147 - lr: 6.2500e-05
# Epoch 103/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0137 - lr: 3.1250e-05
# Epoch 104/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0134 - lr: 3.1250e-05
# Epoch 105/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0135 - lr: 3.1250e-05
# Epoch 106/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0136 - lr: 3.1250e-05
# Epoch 107/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0069Restoring model weights from the end of the best epoch: 71.
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0135 - lr: 3.1250e-05
# Epoch 107: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Loss de treinamento')
plt.plot(history.history['val_loss'], label='Loss de validação')
plt.legend()
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title(f'Loss: {PLOT_TITLE}; Otimizador Adam')
plt.savefig(f'{NOTEBOOK_NAME}/loss_adam.png')

# %% [markdown]
# ## Resultados obtidos

# %%
predictions_train = model.predict(inputs_train)
predictions_test = model.predict(inputs_test)
if NORMALIZE:
    predictions_train = OUTPUT_SCALER.inverse_transform(predictions_train)
    predictions_test = OUTPUT_SCALER.inverse_transform(predictions_test)
    temp_train = OUTPUT_SCALER.inverse_transform(outputs_train)
    temp_test = OUTPUT_SCALER.inverse_transform(outputs_test)
else:
    temp_train = outputs_train
    temp_test = outputs_test

fig, ax = plt.subplots(1, 2, figsize=(12, 7))

ax[0].plot(temp_train, label='Dados reais')
ax[0].plot(predictions_train, label='Predição')
ax[0].legend()
ax[0].set_title('Treinamento')

ax[1].plot(temp_test, label='Dados reais')
ax[1].plot(predictions_test, label='Predição')
ax[1].legend()
ax[1].set_title('Teste')

fig.suptitle(f'Predições {PLOT_TITLE}, otimizador Adam')
plt.savefig(f'{NOTEBOOK_NAME}/predictions_adam.png')
# Out:
# 23/23 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step

# %% [markdown]
# # Rede neural e treinamento (SGD)

# %%
from keras.models import Sequential
from keras.layers import LSTM, InputLayer, Dense
from keras.optimizers import SGD

model = Sequential(name=NOTEBOOK_NAME)
model.add(InputLayer(input_shape=((None, 1)), name='input_layer'))
for i, cell in enumerate(LSTM_COUNT[:-1]):
    model.add(LSTM(cell, return_sequences=True, name=f'lstm_layer_{i + 1}'))
model.add(LSTM(LSTM_COUNT[-1], name=f'lstm_layer_{len(LSTM_COUNT)}'))
model.add(Dense(1, DENSE_ACTIVATION_FUNCTION, name=DENSE_ACTIVATION_FUNCTION))
model.summary()
opt = SGD(learning_rate=INITIAL_LEARNING_RATE, momentum=0.9)
model.compile(loss='mae', optimizer=opt)
# Out:
# Model: "3_increasing_gap"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_layer_1 (LSTM)         (None, 8)                 320
#
#  linear (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 329 (1.29 KB)
# Trainable params: 329 (1.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

history = model.fit(
    inputs_train, outputs_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    shuffle=True,
    validation_batch_size=BATCH_SIZE//2,
    validation_split=0.15,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=EARLY_STOP_PATIENCE,
                      verbose=1, restore_best_weights=True, start_from_epoch=EARLY_STOP_EPOCH),
        ModelCheckpoint(f'{NOTEBOOK_NAME}/model_sgd.h5',
                        save_best_only=True, save_weights_only=True),
        ReduceLRBacktrack(f'{NOTEBOOK_NAME}/model_sgd.h5',
                          monitor='val_loss', patience=LEARNING_RATE_REDUCER_PATIENCE, factor=LEARNING_RATE_REDUCER_FACTOR, verbose=1)
    ]
)
# Recuperando melhor modelo
model.load_weights(f'{NOTEBOOK_NAME}/model_sgd.h5')
# Out:
# Epoch 1/200
# 20/20 [==============================] - 2s 20ms/step - loss: 0.3000 - val_loss: 0.1027 - lr: 0.0010
# Epoch 2/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0585 - val_loss: 0.0942 - lr: 0.0010
# Epoch 3/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0320 - val_loss: 0.0997 - lr: 0.0010
# Epoch 4/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.1042 - lr: 0.0010
# Epoch 5/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0257 - val_loss: 0.0998 - lr: 0.0010
# Epoch 6/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0258 - val_loss: 0.0920 - lr: 0.0010
# Epoch 7/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0239 - val_loss: 0.0896 - lr: 0.0010
# Epoch 8/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0229 - val_loss: 0.0849 - lr: 0.0010
# Epoch 9/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0215 - val_loss: 0.0827 - lr: 0.0010
# Epoch 10/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0213 - val_loss: 0.0757 - lr: 0.0010
# Epoch 11/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0739 - lr: 0.0010
# Epoch 12/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0677 - lr: 0.0010
# Epoch 13/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0642 - lr: 0.0010
# Epoch 14/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0164 - val_loss: 0.0616 - lr: 0.0010
# Epoch 15/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0154 - val_loss: 0.0555 - lr: 0.0010
# Epoch 16/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0145 - val_loss: 0.0499 - lr: 0.0010
# Epoch 17/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0139 - val_loss: 0.0468 - lr: 0.0010
# Epoch 18/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0123 - val_loss: 0.0402 - lr: 0.0010
# Epoch 19/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0115 - val_loss: 0.0377 - lr: 0.0010
# Epoch 20/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.0317 - lr: 0.0010
# Epoch 21/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0275 - lr: 0.0010
# Epoch 22/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0227 - lr: 0.0010
# Epoch 23/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0176 - lr: 0.0010
# Epoch 24/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0152 - lr: 0.0010
# Epoch 25/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0156 - lr: 0.0010
# Epoch 26/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0110 - lr: 0.0010
# Epoch 27/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0096 - lr: 0.0010
# Epoch 28/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0107 - lr: 0.0010
# Epoch 29/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0103 - lr: 0.0010
# Epoch 30/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0140 - lr: 0.0010
# Epoch 31/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0141 - lr: 0.0010
# Epoch 32/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0109 - lr: 0.0010
# Epoch 33/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0121 - lr: 0.0010
# Epoch 34/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0166 - lr: 0.0010
# Epoch 35/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0113 - lr: 0.0010
# Epoch 36/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0153 - lr: 0.0010
# Epoch 37/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0138 - lr: 0.0010
# Epoch 38/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0102 - lr: 0.0010
# Epoch 39/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0144 - lr: 0.0010
# Epoch 40/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0141 - lr: 0.0010
# Epoch 41/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0126 - lr: 0.0010
# Epoch 42/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0147 - lr: 0.0010
# Epoch 43/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0062Backtracking to best model before reducting LR
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0182 - lr: 0.0010
# Epoch 44/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0091 - lr: 5.0000e-04
# Epoch 45/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0101 - lr: 5.0000e-04
# Epoch 46/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0114 - lr: 5.0000e-04
# Epoch 47/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0116 - lr: 5.0000e-04
# Epoch 48/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0108 - lr: 5.0000e-04
# Epoch 49/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0109 - lr: 5.0000e-04
# Epoch 50/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0121 - lr: 5.0000e-04
# Epoch 51/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0134 - lr: 5.0000e-04
# Epoch 52/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0124 - lr: 5.0000e-04
# Epoch 53/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0107 - lr: 5.0000e-04
# Epoch 54/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0105 - lr: 5.0000e-04
# Epoch 55/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0139 - lr: 5.0000e-04
# Epoch 56/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0137 - lr: 5.0000e-04
# Epoch 57/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0135 - lr: 5.0000e-04
# Epoch 58/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0149 - lr: 5.0000e-04
# Epoch 59/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0146 - lr: 5.0000e-04
# Epoch 60/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0043Backtracking to best model before reducting LR
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0131 - lr: 5.0000e-04
# Epoch 61/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0101 - lr: 2.5000e-04
# Epoch 62/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0102 - lr: 2.5000e-04
# Epoch 63/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0096 - lr: 2.5000e-04
# Epoch 64/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0101 - lr: 2.5000e-04
# Epoch 65/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0117 - lr: 2.5000e-04
# Epoch 66/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0104 - lr: 2.5000e-04
# Epoch 67/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0114 - lr: 2.5000e-04
# Epoch 68/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0114 - lr: 2.5000e-04
# Epoch 69/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0117 - lr: 2.5000e-04
# Epoch 70/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0112 - lr: 2.5000e-04
# Epoch 71/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0116 - lr: 2.5000e-04
# Epoch 72/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0126 - lr: 2.5000e-04
# Epoch 73/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0123 - lr: 2.5000e-04
# Epoch 74/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0121 - lr: 2.5000e-04
# Epoch 75/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0119 - lr: 2.5000e-04
# Epoch 76/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0031Backtracking to best model before reducting LR
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0125 - lr: 2.5000e-04
# Epoch 77/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0094 - lr: 1.2500e-04
# Epoch 78/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0097 - lr: 1.2500e-04
# Epoch 79/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 1.2500e-04
# Epoch 80/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0097 - lr: 1.2500e-04
# Epoch 81/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0100 - lr: 1.2500e-04
# Epoch 82/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0100 - lr: 1.2500e-04
# Epoch 83/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 1.2500e-04
# Epoch 84/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 85/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0113 - lr: 1.2500e-04
# Epoch 86/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 87/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0107 - lr: 1.2500e-04
# Epoch 88/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 89/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0104 - lr: 1.2500e-04
# Epoch 90/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 91/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0111 - lr: 1.2500e-04
# Epoch 92/200
# 17/20 [========================>.....] - ETA: 0s - loss: 0.0038Backtracking to best model before reducting LR
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0107 - lr: 1.2500e-04
# Epoch 93/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0093 - lr: 6.2500e-05
# Epoch 94/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0093 - lr: 6.2500e-05
# Epoch 95/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0095 - lr: 6.2500e-05
# Epoch 96/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0097 - lr: 6.2500e-05
# Epoch 97/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0097 - lr: 6.2500e-05
# Epoch 98/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0096 - lr: 6.2500e-05
# Epoch 99/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 6.2500e-05
# Epoch 100/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0094 - lr: 6.2500e-05
# Epoch 101/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0097 - lr: 6.2500e-05
# Epoch 102/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0097 - lr: 6.2500e-05
# Epoch 103/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0097 - lr: 6.2500e-05
# Epoch 104/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0099 - lr: 6.2500e-05
# Epoch 105/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0098 - lr: 6.2500e-05
# Epoch 106/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0101 - lr: 6.2500e-05
# Epoch 107/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0101 - lr: 6.2500e-05
# Epoch 108/200
# 17/20 [========================>.....] - ETA: 0s - loss: 0.0038Backtracking to best model before reducting LR
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0099 - lr: 6.2500e-05
# Epoch 109/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0096 - lr: 3.1250e-05
# Epoch 110/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 111/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0094 - lr: 3.1250e-05
# Epoch 112/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0094 - lr: 3.1250e-05
# Epoch 113/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 114/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 115/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 116/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 117/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 118/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0094 - lr: 3.1250e-05
# Epoch 119/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0096 - lr: 3.1250e-05
# Epoch 120/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 121/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0095 - lr: 3.1250e-05
# Epoch 122/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0097 - lr: 3.1250e-05
# Epoch 123/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0097 - lr: 3.1250e-05
# Epoch 124/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0040Backtracking to best model before reducting LR
#
# Epoch 124: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0096 - lr: 3.1250e-05
# Epoch 125/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0094 - lr: 1.5625e-05
# Epoch 126/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0095 - lr: 1.5625e-05
# Epoch 127/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0094 - lr: 1.5625e-05
# Epoch 128/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0094 - lr: 1.5625e-05
# Epoch 129/200
#  1/20 [>.............................] - ETA: 0s - loss: 0.0032Restoring model weights from the end of the best epoch: 93.
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0094 - lr: 1.5625e-05
# Epoch 129: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Loss de treinamento')
plt.plot(history.history['val_loss'], label='Loss de validação')
plt.legend()
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title(f'Loss: {PLOT_TITLE}; Otimizador SGD')
plt.savefig(f'{NOTEBOOK_NAME}/loss_sgd.png')

# %% [markdown]
# ## Resultados obtidos
#
# Comparando predições para as sequências separadas para teste

# %% [markdown]
# Dados de treinamento: primeiro a rede precisa ser capaz de apresentar um desempenho satisfatório para os dados que foram utilizados em seu treinamento...

# %%
predictions_train = model.predict(inputs_train)
predictions_test = model.predict(inputs_test)
if NORMALIZE:
    predictions_train = OUTPUT_SCALER.inverse_transform(predictions_train)
    predictions_test = OUTPUT_SCALER.inverse_transform(predictions_test)
    temp_train = OUTPUT_SCALER.inverse_transform(outputs_train)
    temp_test = OUTPUT_SCALER.inverse_transform(outputs_test)
else:
    temp_train = outputs_train
    temp_test = outputs_test

fig, ax = plt.subplots(1, 2, figsize=(12, 7))

ax[0].plot(temp_train, label='Dados reais')
ax[0].plot(predictions_train, label='Predição')
ax[0].legend()
ax[0].set_title('Treinamento')

ax[1].plot(temp_test, label='Dados reais')
ax[1].plot(predictions_test, label='Predição')
ax[1].legend()
ax[1].set_title('Teste')

fig.suptitle(f'Predições {PLOT_TITLE}, otimizador SGD')
plt.savefig(f'{NOTEBOOK_NAME}/predictions_sgd.png')
# Out:
# 23/23 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step
