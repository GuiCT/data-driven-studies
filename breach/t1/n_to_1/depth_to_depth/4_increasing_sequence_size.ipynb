# %% [markdown]
# **Constantes**
#
# Tamanho da sequência utilizada, tamanho da janela, frequência de _cutoff_, tamanho de lote, etc.

# %%
BATCH_SIZE = 32
CUTOFF_FREQUENCY = 0.009
DATA_FOLDER = '../../data'
DENSE_ACTIVATION_FUNCTION = 'linear'
EPOCHS = 200
INITIAL_LEARNING_RATE = 0.001
LSTM_COUNT = [8]
NORMALIZE = True
NOTEBOOK_NAME = '4_increasing_sequence_size'
SAMPLE_RATE = 1
SEQUENCE_GAP = 10
SEQUENCE_SIZE = 25
PATINCE_EARLY_STOP = 36
PATIENCE_LR = 16
TEST_SPLIT_FACTOR = 3

# %%
from keras.callbacks import ReduceLROnPlateau
from tensorflow.python.platform import tf_logging as logging


class ReduceLRBacktrack(ReduceLROnPlateau):
    def __init__(self, best_path, *args, **kwargs):
        super(ReduceLRBacktrack, self).__init__(*args, **kwargs)
        self.best_path = best_path

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.monitor)
        if current is None:
            logging.warning('Reduce LR on plateau conditioned on metric `%s` '
                            'which is not available. Available metrics are: %s',
                            self.monitor, ','.join(list(logs.keys())))
        if not self.monitor_op(current, self.best):  # not new best
            if not self.in_cooldown():  # and we're not in cooldown
                if self.wait+1 >= self.patience:  # going to reduce lr
                    # load best model so far
                    print("Backtracking to best model before reducting LR")
                    self.model.load_weights(self.best_path)

        super().on_epoch_end(epoch, logs)  # actually reduce LR
# Out:
# 2023-10-25 21:42:23.783294: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-25 21:42:23.811831: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-25 21:42:23.811857: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-25 21:42:23.811878: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-25 21:42:23.817144: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-25 21:42:23.817533: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-25 21:42:24.692803: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Estado para reproduzir os mesmos resultados

# %%
from keras.utils import set_random_seed

set_random_seed(42)

# %% [markdown]
# # Preparação dos dados
#
# Carregando os arquivos .csv que contém os dados de altura da lâmina e vazão.

# %% [markdown]
# ## Altura

# %%
import pandas as pd

# %%
depth_df = pd.read_csv(f'{DATA_FOLDER}/water_depth_reservoir_Test1.csv')
display(depth_df)
# Out:
#       time (s)  water depth (m)  Unnamed: 2
# 0            0          0.45045         NaN
# 1            1          0.45070         NaN
# 2            2          0.45086         NaN
# 3            3          0.45096         NaN
# 4            4          0.45100         NaN
# ...        ...              ...         ...
# 4313      4313          0.43703         NaN
# 4314      4314          0.43711         NaN
# 4315      4315          0.43720         NaN
# 4316      4316          0.43729         NaN
# 4317      4317          0.43737         NaN
#
# [4318 rows x 3 columns]

# %% [markdown]
# Devido à forma como o CSV está organizado, há uma coluna extra indesejada.
#
# Para corrigir isso, podemos dropar essa coluna utilizando pandas.

# %%
depth_df = depth_df.drop(columns=[depth_df.columns[-1]])
display(depth_df)
# Out:
#       time (s)  water depth (m)
# 0            0          0.45045
# 1            1          0.45070
# 2            2          0.45086
# 3            3          0.45096
# 4            4          0.45100
# ...        ...              ...
# 4313      4313          0.43703
# 4314      4314          0.43711
# 4315      4315          0.43720
# 4316      4316          0.43729
# 4317      4317          0.43737
#
# [4318 rows x 2 columns]

# %% [markdown]
# Ignorando coluna com o valor do tempo, pois a coluna de índice é equivalente.

# %%
depth_df = depth_df.drop(columns=[depth_df.columns[0]])
display(depth_df)
# Out:
#       water depth (m)
# 0             0.45045
# 1             0.45070
# 2             0.45086
# 3             0.45096
# 4             0.45100
# ...               ...
# 4313          0.43703
# 4314          0.43711
# 4315          0.43720
# 4316          0.43729
# 4317          0.43737
#
# [4318 rows x 1 columns]

# %% [markdown]
# ## Vazão

# %%
discharge_df = pd.read_csv(f'{DATA_FOLDER}/discharge_inlet_Test1.csv')
display(discharge_df)
# Out:
#       time (s)  inlet discharge (m3/s)
# 0            1                0.000630
# 1            1                0.000388
# 2            1                0.000203
# 3            1                0.000070
# 4            4               -0.000020
# ...        ...                     ...
# 4313      4313                0.024713
# 4314      4314                0.024809
# 4315      4315                0.024889
# 4316      4316                0.024951
# 4317      4317                0.024999
#
# [4318 rows x 2 columns]

# %% [markdown]
# Na coluna indicando o tempo em segundos, o valor "1" está sendo repetido 4 vezes.
#
# Tendo em vista que os valores da vazão mudaram para essas 4 entradas, vamos assumir que isso foi um erro de registro e que os valores são na realidade 0, 1, 2, ...
#
# Essa mudança torna esse dataset consistente com o de altura carregado anteriormente.
#
# Da mesma forma como fizemos anteriormente, podemos tratar a coluna de índices como nosso indicador de tempo.

# %%
discharge_df = discharge_df.drop(columns=[discharge_df.columns[0]])
display(discharge_df)
# Out:
#       inlet discharge (m3/s)
# 0                   0.000630
# 1                   0.000388
# 2                   0.000203
# 3                   0.000070
# 4                  -0.000020
# ...                      ...
# 4313                0.024713
# 4314                0.024809
# 4315                0.024889
# 4316                0.024951
# 4317                0.024999
#
# [4318 rows x 1 columns]

# %% [markdown]
# Podemos unir os dados em um só DF, o que facilita a preparação dos mesmos

# %%
unified_df = pd.concat([discharge_df, depth_df], axis=1)
display(unified_df)
# Out:
#       inlet discharge (m3/s)  water depth (m)
# 0                   0.000630          0.45045
# 1                   0.000388          0.45070
# 2                   0.000203          0.45086
# 3                   0.000070          0.45096
# 4                  -0.000020          0.45100
# ...                      ...              ...
# 4313                0.024713          0.43703
# 4314                0.024809          0.43711
# 4315                0.024889          0.43720
# 4316                0.024951          0.43729
# 4317                0.024999          0.43737
#
# [4318 rows x 2 columns]

# %% [markdown]
# ## Remoção de ruídos

# %%
from scipy.signal import butter, filtfilt

smoothed_df = unified_df.copy()

original_discharge = smoothed_df['inlet discharge (m3/s)'].values
b, a = butter(N=6, Wn=CUTOFF_FREQUENCY/(0.5*SAMPLE_RATE), btype='low')
y = filtfilt(b, a, original_discharge)
smoothed_df['inlet discharge (m3/s)'] = y

original_depth = smoothed_df['water depth (m)'].values
b, a = butter(N=6, Wn=CUTOFF_FREQUENCY/(0.5*SAMPLE_RATE), btype='low')
y = filtfilt(b, a, original_depth)
smoothed_df['water depth (m)'] = y

# %% [markdown]
# Verificando resultado da remoção de ruído

# %%
import matplotlib.pyplot as plt

plt.plot(unified_df['inlet discharge (m3/s)'])
plt.plot(smoothed_df['inlet discharge (m3/s)'])
plt.show()

plt.plot(unified_df['inlet discharge (m3/s)'].values[:2000])
plt.plot(smoothed_df['inlet discharge (m3/s)'].values[:2000])
plt.show()

plt.plot(unified_df['water depth (m)'])
plt.plot(smoothed_df['water depth (m)'])
plt.show()

plt.plot(unified_df['water depth (m)'].values[:2000])
plt.plot(smoothed_df['water depth (m)'].values[:2000])
plt.show()

# %% [markdown]
# Convertendo o DataFrame em array numpy para facilitar acesso.

# %%
unified = smoothed_df.to_numpy()

# %% [markdown]
# ## Normalização

# %%
from sklearn.preprocessing import MinMaxScaler

unified_scaler = MinMaxScaler()
water_depth_scaler = MinMaxScaler()
inlet_discharge_scaler = MinMaxScaler()
water_depth_scaler.fit(unified[:, 1].reshape(-1, 1))
inlet_discharge_scaler.fit(unified[:, 0].reshape(-1, 1))
unified_scaler.fit(unified)
# Out:
# MinMaxScaler()

# %%
if NORMALIZE:
    unified = unified_scaler.transform(unified)

# %% [markdown]
# ## Estrutura dos dados de treinamento

# %%
# Obtendo índices lower..upper
i = 0
lower = list()
upper = list()
while i + SEQUENCE_SIZE < len(unified):
    lower.append(i)
    upper.append(i + SEQUENCE_SIZE)
    print(f"[{i}, {i + SEQUENCE_SIZE})")
    i += SEQUENCE_GAP
# Out:
# [0, 25)
# [10, 35)
# [20, 45)
# [30, 55)
# [40, 65)
# [50, 75)
# [60, 85)
# [70, 95)
# [80, 105)
# [90, 115)
# [100, 125)
# [110, 135)
# [120, 145)
# [130, 155)
# [140, 165)
# [150, 175)
# [160, 185)
# [170, 195)
# [180, 205)
# [190, 215)
# [200, 225)
# [210, 235)
# [220, 245)
# [230, 255)
# [240, 265)
# [250, 275)
# [260, 285)
# [270, 295)
# [280, 305)
# [290, 315)
# [300, 325)
# [310, 335)
# [320, 345)
# [330, 355)
# [340, 365)
# [350, 375)
# [360, 385)
# [370, 395)
# [380, 405)
# [390, 415)
# [400, 425)
# [410, 435)
# [420, 445)
# [430, 455)
# [440, 465)
# [450, 475)
# [460, 485)
# [470, 495)
# [480, 505)
# [490, 515)
# [500, 525)
# [510, 535)
# [520, 545)
# [530, 555)
# [540, 565)
# [550, 575)
# [560, 585)
# [570, 595)
# [580, 605)
# [590, 615)
# [600, 625)
# [610, 635)
# [620, 645)
# [630, 655)
# [640, 665)
# [650, 675)
# [660, 685)
# [670, 695)
# [680, 705)
# [690, 715)
# [700, 725)
# [710, 735)
# [720, 745)
# [730, 755)
# [740, 765)
# [750, 775)
# [760, 785)
# [770, 795)
# [780, 805)
# [790, 815)
# [800, 825)
# [810, 835)
# [820, 845)
# [830, 855)
# [840, 865)
# [850, 875)
# [860, 885)
# [870, 895)
# [880, 905)
# [890, 915)
# [900, 925)
# [910, 935)
# [920, 945)
# [930, 955)
# [940, 965)
# [950, 975)
# [960, 985)
# [970, 995)
# [980, 1005)
# [990, 1015)
# [1000, 1025)
# [1010, 1035)
# [1020, 1045)
# [1030, 1055)
# [1040, 1065)
# [1050, 1075)
# [1060, 1085)
# [1070, 1095)
# [1080, 1105)
# [1090, 1115)
# [1100, 1125)
# [1110, 1135)
# [1120, 1145)
# [1130, 1155)
# [1140, 1165)
# [1150, 1175)
# [1160, 1185)
# [1170, 1195)
# [1180, 1205)
# [1190, 1215)
# [1200, 1225)
# [1210, 1235)
# [1220, 1245)
# [1230, 1255)
# [1240, 1265)
# [1250, 1275)
# [1260, 1285)
# [1270, 1295)
# [1280, 1305)
# [1290, 1315)
# [1300, 1325)
# [1310, 1335)
# [1320, 1345)
# [1330, 1355)
# [1340, 1365)
# [1350, 1375)
# [1360, 1385)
# [1370, 1395)
# [1380, 1405)
# [1390, 1415)
# [1400, 1425)
# [1410, 1435)
# [1420, 1445)
# [1430, 1455)
# [1440, 1465)
# [1450, 1475)
# [1460, 1485)
# [1470, 1495)
# [1480, 1505)
# [1490, 1515)
# [1500, 1525)
# [1510, 1535)
# [1520, 1545)
# [1530, 1555)
# [1540, 1565)
# [1550, 1575)
# [1560, 1585)
# [1570, 1595)
# [1580, 1605)
# [1590, 1615)
# [1600, 1625)
# [1610, 1635)
# [1620, 1645)
# [1630, 1655)
# [1640, 1665)
# [1650, 1675)
# [1660, 1685)
# [1670, 1695)
# [1680, 1705)
# [1690, 1715)
# [1700, 1725)
# [1710, 1735)
# [1720, 1745)
# [1730, 1755)
# [1740, 1765)
# [1750, 1775)
# [1760, 1785)
# [1770, 1795)
# [1780, 1805)
# [1790, 1815)
# [1800, 1825)
# [1810, 1835)
# [1820, 1845)
# [1830, 1855)
# [1840, 1865)
# [1850, 1875)
# [1860, 1885)
# [1870, 1895)
# [1880, 1905)
# [1890, 1915)
# [1900, 1925)
# [1910, 1935)
# [1920, 1945)
# [1930, 1955)
# [1940, 1965)
# [1950, 1975)
# [1960, 1985)
# [1970, 1995)
# [1980, 2005)
# [1990, 2015)
# [2000, 2025)
# [2010, 2035)
# [2020, 2045)
# [2030, 2055)
# [2040, 2065)
# [2050, 2075)
# [2060, 2085)
# [2070, 2095)
# [2080, 2105)
# [2090, 2115)
# [2100, 2125)
# [2110, 2135)
# [2120, 2145)
# [2130, 2155)
# [2140, 2165)
# [2150, 2175)
# [2160, 2185)
# [2170, 2195)
# [2180, 2205)
# [2190, 2215)
# [2200, 2225)
# [2210, 2235)
# [2220, 2245)
# [2230, 2255)
# [2240, 2265)
# [2250, 2275)
# [2260, 2285)
# [2270, 2295)
# [2280, 2305)
# [2290, 2315)
# [2300, 2325)
# [2310, 2335)
# [2320, 2345)
# [2330, 2355)
# [2340, 2365)
# [2350, 2375)
# [2360, 2385)
# [2370, 2395)
# [2380, 2405)
# [2390, 2415)
# [2400, 2425)
# [2410, 2435)
# [2420, 2445)
# [2430, 2455)
# [2440, 2465)
# [2450, 2475)
# [2460, 2485)
# [2470, 2495)
# [2480, 2505)
# [2490, 2515)
# [2500, 2525)
# [2510, 2535)
# [2520, 2545)
# [2530, 2555)
# [2540, 2565)
# [2550, 2575)
# [2560, 2585)
# [2570, 2595)
# [2580, 2605)
# [2590, 2615)
# [2600, 2625)
# [2610, 2635)
# [2620, 2645)
# [2630, 2655)
# [2640, 2665)
# [2650, 2675)
# [2660, 2685)
# [2670, 2695)
# [2680, 2705)
# [2690, 2715)
# [2700, 2725)
# [2710, 2735)
# [2720, 2745)
# [2730, 2755)
# [2740, 2765)
# [2750, 2775)
# [2760, 2785)
# [2770, 2795)
# [2780, 2805)
# [2790, 2815)
# [2800, 2825)
# [2810, 2835)
# [2820, 2845)
# [2830, 2855)
# [2840, 2865)
# [2850, 2875)
# [2860, 2885)
# [2870, 2895)
# [2880, 2905)
# [2890, 2915)
# [2900, 2925)
# [2910, 2935)
# [2920, 2945)
# [2930, 2955)
# [2940, 2965)
# [2950, 2975)
# [2960, 2985)
# [2970, 2995)
# [2980, 3005)
# [2990, 3015)
# [3000, 3025)
# [3010, 3035)
# [3020, 3045)
# [3030, 3055)
# [3040, 3065)
# [3050, 3075)
# [3060, 3085)
# [3070, 3095)
# [3080, 3105)
# [3090, 3115)
# [3100, 3125)
# [3110, 3135)
# [3120, 3145)
# [3130, 3155)
# [3140, 3165)
# [3150, 3175)
# [3160, 3185)
# [3170, 3195)
# [3180, 3205)
# [3190, 3215)
# [3200, 3225)
# [3210, 3235)
# [3220, 3245)
# [3230, 3255)
# [3240, 3265)
# [3250, 3275)
# [3260, 3285)
# [3270, 3295)
# [3280, 3305)
# [3290, 3315)
# [3300, 3325)
# [3310, 3335)
# [3320, 3345)
# [3330, 3355)
# [3340, 3365)
# [3350, 3375)
# [3360, 3385)
# [3370, 3395)
# [3380, 3405)
# [3390, 3415)
# [3400, 3425)
# [3410, 3435)
# [3420, 3445)
# [3430, 3455)
# [3440, 3465)
# [3450, 3475)
# [3460, 3485)
# [3470, 3495)
# [3480, 3505)
# [3490, 3515)
# [3500, 3525)
# [3510, 3535)
# [3520, 3545)
# [3530, 3555)
# [3540, 3565)
# [3550, 3575)
# [3560, 3585)
# [3570, 3595)
# [3580, 3605)
# [3590, 3615)
# [3600, 3625)
# [3610, 3635)
# [3620, 3645)
# [3630, 3655)
# [3640, 3665)
# [3650, 3675)
# [3660, 3685)
# [3670, 3695)
# [3680, 3705)
# [3690, 3715)
# [3700, 3725)
# [3710, 3735)
# [3720, 3745)
# [3730, 3755)
# [3740, 3765)
# [3750, 3775)
# [3760, 3785)
# [3770, 3795)
# [3780, 3805)
# [3790, 3815)
# [3800, 3825)
# [3810, 3835)
# [3820, 3845)
# [3830, 3855)
# [3840, 3865)
# [3850, 3875)
# [3860, 3885)
# [3870, 3895)
# [3880, 3905)
# [3890, 3915)
# [3900, 3925)
# [3910, 3935)
# [3920, 3945)
# [3930, 3955)
# [3940, 3965)
# [3950, 3975)
# [3960, 3985)
# [3970, 3995)
# [3980, 4005)
# [3990, 4015)
# [4000, 4025)
# [4010, 4035)
# [4020, 4045)
# [4030, 4055)
# [4040, 4065)
# [4050, 4075)
# [4060, 4085)
# [4070, 4095)
# [4080, 4105)
# [4090, 4115)
# [4100, 4125)
# [4110, 4135)
# [4120, 4145)
# [4130, 4155)
# [4140, 4165)
# [4150, 4175)
# [4160, 4185)
# [4170, 4195)
# [4180, 4205)
# [4190, 4215)
# [4200, 4225)
# [4210, 4235)
# [4220, 4245)
# [4230, 4255)
# [4240, 4265)
# [4250, 4275)
# [4260, 4285)
# [4270, 4295)
# [4280, 4305)
# [4290, 4315)

# %% [markdown]
# Construindo sequência de inputs e outputs utilizadas pela rede.
#
# No caso desse notebook:
#
# - Input: Altura da lâmina
# - Output: Altura da lâmina

# %%
import numpy as np

number_of_sequences = len(lower)
display("Quantidade de sequências", number_of_sequences)

TRAINING_SIZE = int(number_of_sequences * (1 - 1 / TEST_SPLIT_FACTOR))
display("Quantidade de sequências de treinamento", TRAINING_SIZE)

inputs = np.zeros((number_of_sequences, SEQUENCE_SIZE, 1))
outputs = np.zeros((number_of_sequences, 1))
for i in range(number_of_sequences):
    inputs[i, :] = unified[lower[i]:upper[i], 1].reshape(-1, 1)
    outputs[i, :] = unified[upper[i], 1]

inputs_train = inputs[:TRAINING_SIZE]
outputs_train = outputs[:TRAINING_SIZE]
inputs_test = inputs[TRAINING_SIZE:]
outputs_test = outputs[TRAINING_SIZE:]
display("Shapes", inputs_train.shape, outputs_train.shape,
        inputs_test.shape, outputs_test.shape)
# Out:
# 'Quantidade de sequências'
# 430
# 'Quantidade de sequências de treinamento'
# 286
# 'Shapes'
# (286, 25, 1)
# (286, 1)
# (144, 25, 1)
# (144, 1)

# %% [markdown]
# # Rede neural e treinamento (Adam)

# %%
from keras.models import Sequential
from keras.layers import LSTM, InputLayer, Dense
from keras.optimizers import Adam
from keras.utils import plot_model
import os

if os.path.exists(f'{NOTEBOOK_NAME}/model.png'):
    os.remove(f'{NOTEBOOK_NAME}/model.png')

model = Sequential(name=NOTEBOOK_NAME)
model.add(InputLayer(input_shape=((None, 1)), name='input_layer'))
for i, cell in enumerate(LSTM_COUNT[:-1]):
    model.add(LSTM(cell, return_sequences=True, name=f'lstm_layer_{i + 1}'))
model.add(LSTM(LSTM_COUNT[-1], name=f'lstm_layer_{len(LSTM_COUNT)}'))
model.add(Dense(1, DENSE_ACTIVATION_FUNCTION, name=DENSE_ACTIVATION_FUNCTION))
model.summary()
opt = Adam(learning_rate=INITIAL_LEARNING_RATE, amsgrad=True)

if not os.path.exists(NOTEBOOK_NAME):
    os.mkdir(NOTEBOOK_NAME)
plot_model(model, f'{NOTEBOOK_NAME}/model.png', show_shapes=True)
model.compile(loss='mae', optimizer=opt)
# Out:
# Model: "4_increasing_sequence_size"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_layer_1 (LSTM)         (None, 8)                 320
#
#  linear (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 329 (1.29 KB)
# Trainable params: 329 (1.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-10-25 21:42:26.581450: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 21:42:26.581818: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

history = model.fit(
    inputs_train, outputs_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    shuffle=True,
    validation_batch_size=BATCH_SIZE//2,
    validation_split=0.15,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=PATINCE_EARLY_STOP,
                      verbose=1, restore_best_weights=True, start_from_epoch=66),
        ModelCheckpoint(f'{NOTEBOOK_NAME}/model_adam.h5',
                        save_best_only=True, save_weights_only=True),
        ReduceLRBacktrack(f'{NOTEBOOK_NAME}/model_adam.h5',
                          monitor='val_loss', patience=PATIENCE_LR, factor=0.5, verbose=1)
    ]
)
# Recuperando melhor modelo
model.load_weights(f'{NOTEBOOK_NAME}/model_adam.h5')
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 57ms/step - loss: 0.6030 - val_loss: 0.3977 - lr: 0.0010
# Epoch 2/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4882 - val_loss: 0.2942 - lr: 0.0010
# Epoch 3/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3735 - val_loss: 0.1890 - lr: 0.0010
# Epoch 4/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2577 - val_loss: 0.1231 - lr: 0.0010
# Epoch 5/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1371 - val_loss: 0.1203 - lr: 0.0010
# Epoch 6/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0481 - val_loss: 0.1626 - lr: 0.0010
# Epoch 7/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0586 - val_loss: 0.1538 - lr: 0.0010
# Epoch 8/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0390 - val_loss: 0.1302 - lr: 0.0010
# Epoch 9/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0418 - val_loss: 0.1312 - lr: 0.0010
# Epoch 10/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0370 - val_loss: 0.1411 - lr: 0.0010
# Epoch 11/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0370 - val_loss: 0.1352 - lr: 0.0010
# Epoch 12/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0348 - val_loss: 0.1291 - lr: 0.0010
# Epoch 13/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0344 - val_loss: 0.1286 - lr: 0.0010
# Epoch 14/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0341 - val_loss: 0.1285 - lr: 0.0010
# Epoch 15/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0333 - val_loss: 0.1228 - lr: 0.0010
# Epoch 16/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0325 - val_loss: 0.1216 - lr: 0.0010
# Epoch 17/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0318 - val_loss: 0.1186 - lr: 0.0010
# Epoch 18/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0312 - val_loss: 0.1145 - lr: 0.0010
# Epoch 19/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0304 - val_loss: 0.1135 - lr: 0.0010
# Epoch 20/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0297 - val_loss: 0.1088 - lr: 0.0010
# Epoch 21/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0291 - val_loss: 0.1058 - lr: 0.0010
# Epoch 22/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0282 - val_loss: 0.1021 - lr: 0.0010
# Epoch 23/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0274 - val_loss: 0.0994 - lr: 0.0010
# Epoch 24/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0266 - val_loss: 0.0971 - lr: 0.0010
# Epoch 25/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0256 - val_loss: 0.0908 - lr: 0.0010
# Epoch 26/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0252 - val_loss: 0.0890 - lr: 0.0010
# Epoch 27/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0240 - val_loss: 0.0856 - lr: 0.0010
# Epoch 28/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0231 - val_loss: 0.0814 - lr: 0.0010
# Epoch 29/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0222 - val_loss: 0.0772 - lr: 0.0010
# Epoch 30/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0213 - val_loss: 0.0743 - lr: 0.0010
# Epoch 31/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0202 - val_loss: 0.0700 - lr: 0.0010
# Epoch 32/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0193 - val_loss: 0.0646 - lr: 0.0010
# Epoch 33/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0186 - val_loss: 0.0631 - lr: 0.0010
# Epoch 34/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0172 - val_loss: 0.0551 - lr: 0.0010
# Epoch 35/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0171 - val_loss: 0.0578 - lr: 0.0010
# Epoch 36/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0173 - val_loss: 0.0479 - lr: 0.0010
# Epoch 37/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0443 - lr: 0.0010
# Epoch 38/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0447 - lr: 0.0010
# Epoch 39/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0392 - lr: 0.0010
# Epoch 40/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0112 - val_loss: 0.0345 - lr: 0.0010
# Epoch 41/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0313 - lr: 0.0010
# Epoch 42/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0274 - lr: 0.0010
# Epoch 43/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0085 - val_loss: 0.0251 - lr: 0.0010
# Epoch 44/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0211 - lr: 0.0010
# Epoch 45/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0203 - lr: 0.0010
# Epoch 46/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0078 - val_loss: 0.0174 - lr: 0.0010
# Epoch 47/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0150 - lr: 0.0010
# Epoch 48/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0126 - lr: 0.0010
# Epoch 49/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0116 - lr: 0.0010
# Epoch 50/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0112 - lr: 0.0010
# Epoch 51/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0109 - lr: 0.0010
# Epoch 52/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0114 - lr: 0.0010
# Epoch 53/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0123 - lr: 0.0010
# Epoch 54/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0114 - lr: 0.0010
# Epoch 55/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0113 - lr: 0.0010
# Epoch 56/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0108 - lr: 0.0010
# Epoch 57/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0103 - lr: 0.0010
# Epoch 58/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0105 - lr: 0.0010
# Epoch 59/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0112 - lr: 0.0010
# Epoch 60/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0112 - lr: 0.0010
# Epoch 61/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0115 - lr: 0.0010
# Epoch 62/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0114 - lr: 0.0010
# Epoch 63/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0102 - lr: 0.0010
# Epoch 64/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0102 - lr: 0.0010
# Epoch 65/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0106 - lr: 0.0010
# Epoch 66/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0096 - lr: 0.0010
# Epoch 67/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0099 - lr: 0.0010
# Epoch 68/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0096 - lr: 0.0010
# Epoch 69/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0099 - lr: 0.0010
# Epoch 70/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0092 - lr: 0.0010
# Epoch 71/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0092 - lr: 0.0010
# Epoch 72/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0094 - lr: 0.0010
# Epoch 73/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0092 - lr: 0.0010
# Epoch 74/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0091 - lr: 0.0010
# Epoch 75/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0089 - lr: 0.0010
# Epoch 76/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0088 - lr: 0.0010
# Epoch 77/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0088 - lr: 0.0010
# Epoch 78/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0086 - lr: 0.0010
# Epoch 79/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0093 - lr: 0.0010
# Epoch 80/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0086 - lr: 0.0010
# Epoch 81/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0083 - lr: 0.0010
# Epoch 82/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0082 - lr: 0.0010
# Epoch 83/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0081 - lr: 0.0010
# Epoch 84/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0080 - lr: 0.0010
# Epoch 85/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0081 - lr: 0.0010
# Epoch 86/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0078 - lr: 0.0010
# Epoch 87/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0079 - lr: 0.0010
# Epoch 88/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0077 - lr: 0.0010
# Epoch 89/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0075 - lr: 0.0010
# Epoch 90/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0074 - lr: 0.0010
# Epoch 91/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0075 - lr: 0.0010
# Epoch 92/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0074 - lr: 0.0010
# Epoch 93/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0071 - lr: 0.0010
# Epoch 94/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0070 - lr: 0.0010
# Epoch 95/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0070 - lr: 0.0010
# Epoch 96/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0070 - lr: 0.0010
# Epoch 97/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0068 - lr: 0.0010
# Epoch 98/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0067 - lr: 0.0010
# Epoch 99/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0067 - lr: 0.0010
# Epoch 100/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0064 - lr: 0.0010
# Epoch 101/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0063 - lr: 0.0010
# Epoch 102/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0062 - lr: 0.0010
# Epoch 103/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0062 - lr: 0.0010
# Epoch 104/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0060 - lr: 0.0010
# Epoch 105/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0060 - lr: 0.0010
# Epoch 106/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0058 - lr: 0.0010
# Epoch 107/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0057 - lr: 0.0010
# Epoch 108/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0055 - lr: 0.0010
# Epoch 109/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0054 - lr: 0.0010
# Epoch 110/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0054 - lr: 0.0010
# Epoch 111/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0052 - lr: 0.0010
# Epoch 112/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0052 - lr: 0.0010
# Epoch 113/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0052 - lr: 0.0010
# Epoch 114/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0052 - lr: 0.0010
# Epoch 115/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0053 - lr: 0.0010
# Epoch 116/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0050 - lr: 0.0010
# Epoch 117/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0065 - lr: 0.0010
# Epoch 118/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0063 - lr: 0.0010
# Epoch 119/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0048 - lr: 0.0010
# Epoch 120/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0046 - lr: 0.0010
# Epoch 121/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0051 - lr: 0.0010
# Epoch 122/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0047 - lr: 0.0010
# Epoch 123/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0053 - lr: 0.0010
# Epoch 124/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0057 - lr: 0.0010
# Epoch 125/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0048 - lr: 0.0010
# Epoch 126/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0055 - lr: 0.0010
# Epoch 127/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0049 - lr: 0.0010
# Epoch 128/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0056 - lr: 0.0010
# Epoch 129/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0045 - lr: 0.0010
# Epoch 130/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0047 - lr: 0.0010
# Epoch 131/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0047 - lr: 0.0010
# Epoch 132/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0052 - lr: 0.0010
# Epoch 133/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0050 - lr: 0.0010
# Epoch 134/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0057 - lr: 0.0010
# Epoch 135/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0051 - lr: 0.0010
# Epoch 136/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0050 - lr: 0.0010
# Epoch 137/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0051 - lr: 0.0010
# Epoch 138/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0057 - lr: 0.0010
# Epoch 139/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0052 - lr: 0.0010
# Epoch 140/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0054 - lr: 0.0010
# Epoch 141/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0054 - lr: 0.0010
# Epoch 142/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0053 - lr: 0.0010
# Epoch 143/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0058 - lr: 0.0010
# Epoch 144/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0061 - lr: 0.0010
# Epoch 145/200
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0013Backtracking to best model before reducting LR
#
# Epoch 145: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0067 - lr: 0.0010
# Epoch 146/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0045 - lr: 5.0000e-04
# Epoch 147/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0048 - lr: 5.0000e-04
# Epoch 148/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0050 - lr: 5.0000e-04
# Epoch 149/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0051 - lr: 5.0000e-04
# Epoch 150/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0049 - lr: 5.0000e-04
# Epoch 151/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0048 - lr: 5.0000e-04
# Epoch 152/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0047 - lr: 5.0000e-04
# Epoch 153/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0048 - lr: 5.0000e-04
# Epoch 154/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0055 - lr: 5.0000e-04
# Epoch 155/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0053 - lr: 5.0000e-04
# Epoch 156/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0053 - lr: 5.0000e-04
# Epoch 157/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0051 - lr: 5.0000e-04
# Epoch 158/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0048 - lr: 5.0000e-04
# Epoch 159/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0050 - lr: 5.0000e-04
# Epoch 160/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0054 - lr: 5.0000e-04
# Epoch 161/200
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0014Backtracking to best model before reducting LR
#
# Epoch 161: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0054 - lr: 5.0000e-04
# Epoch 162/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0051 - lr: 2.5000e-04
# Epoch 163/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0050 - lr: 2.5000e-04
# Epoch 164/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0048 - lr: 2.5000e-04
# Epoch 165/200
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0016Restoring model weights from the end of the best epoch: 129.
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0047 - lr: 2.5000e-04
# Epoch 165: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Loss de treinamento')
plt.plot(history.history['val_loss'], label='Loss de validação')
plt.legend()
plt.savefig(f'{NOTEBOOK_NAME}/loss_adam.png')

# %% [markdown]
# ## Resultados obtidos
#
# Comparando predições para as sequências separadas para teste

# %% [markdown]
# Dados de treinamento: primeiro a rede precisa ser capaz de apresentar um desempenho satisfatório para os dados que foram utilizados em seu treinamento...

# %%
predictions = model.predict(inputs_train)
if NORMALIZE:
    predictions = inlet_discharge_scaler.inverse_transform(predictions)
    temp = inlet_discharge_scaler.inverse_transform(outputs_train)
else:
    temp = outputs_train

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(temp, label='Dados de treinamento')
ax[0].plot(predictions, label='Predição')
ax[0].legend()
ax[0].set_title('Treinamento')

# zoom

ax[1].plot(temp[:200], label='Dados de treinamento')
ax[1].plot(predictions[:200], label='Predição')
ax[1].legend()
ax[1].set_title('Treinamento (primeiros 200)')
plt.savefig(f'{NOTEBOOK_NAME}/train_adam.png')
# Out:
# 9/9 [==============================] - 0s 1ms/step

# %% [markdown]
# Dados de teste: agora é a hora da verdade.

# %%
predictions = model.predict(inputs_test)
if NORMALIZE:
    predictions = inlet_discharge_scaler.inverse_transform(predictions)
    temp = inlet_discharge_scaler.inverse_transform(outputs_test)
else:
    temp = outputs_test

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(temp, label='Dados de teste')
ax[0].plot(predictions, label='Predição')
ax[0].legend()
ax[0].set_title('Teste')

# zoom

ax[1].plot(temp[:200], label='Dados de teste')
ax[1].plot(predictions[:200], label='Predição')
ax[1].legend()
ax[1].set_title('Teste (primeiros 200)')
plt.savefig(f'{NOTEBOOK_NAME}/test_adam.png')
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# # Rede neural e treinamento (SGD)

# %%
from keras.models import Sequential
from keras.layers import LSTM, InputLayer, Dense
from keras.optimizers import SGD

model = Sequential(name=NOTEBOOK_NAME)
model.add(InputLayer(input_shape=((None, 1)), name='input_layer'))
for i, cell in enumerate(LSTM_COUNT[:-1]):
    model.add(LSTM(cell, return_sequences=True, name=f'lstm_layer_{i + 1}'))
model.add(LSTM(LSTM_COUNT[-1], name=f'lstm_layer_{len(LSTM_COUNT)}'))
model.add(Dense(1, DENSE_ACTIVATION_FUNCTION, name=DENSE_ACTIVATION_FUNCTION))
model.summary()
opt = SGD(learning_rate=INITIAL_LEARNING_RATE, momentum=0.9)
model.compile(loss='mae', optimizer=opt)
# Out:
# Model: "4_increasing_sequence_size"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_layer_1 (LSTM)         (None, 8)                 320
#
#  linear (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 329 (1.29 KB)
# Trainable params: 329 (1.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

history = model.fit(
    inputs_train, outputs_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    shuffle=True,
    validation_batch_size=BATCH_SIZE//2,
    validation_split=0.15,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=PATINCE_EARLY_STOP,
                      verbose=1, restore_best_weights=True, start_from_epoch=66),
        ModelCheckpoint(f'{NOTEBOOK_NAME}/model_sgd.h5',
                        save_best_only=True, save_weights_only=True),
        ReduceLRBacktrack(f'{NOTEBOOK_NAME}/model_sgd.h5',
                          monitor='val_loss', patience=PATIENCE_LR, factor=0.5, verbose=1)
    ]
)
# Recuperando melhor modelo
model.load_weights(f'{NOTEBOOK_NAME}/model_sgd.h5')
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 50ms/step - loss: 0.4071 - val_loss: 0.2402 - lr: 0.0010
# Epoch 2/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2465 - val_loss: 0.0929 - lr: 0.0010
# Epoch 3/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0599 - val_loss: 0.1629 - lr: 0.0010
# Epoch 4/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0785 - val_loss: 0.1256 - lr: 0.0010
# Epoch 5/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0389 - val_loss: 0.0966 - lr: 0.0010
# Epoch 6/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.1220 - lr: 0.0010
# Epoch 7/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.1065 - lr: 0.0010
# Epoch 8/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0310 - val_loss: 0.1069 - lr: 0.0010
# Epoch 9/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0274 - val_loss: 0.1113 - lr: 0.0010
# Epoch 10/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0271 - val_loss: 0.1023 - lr: 0.0010
# Epoch 11/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0270 - val_loss: 0.1048 - lr: 0.0010
# Epoch 12/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0263 - val_loss: 0.1022 - lr: 0.0010
# Epoch 13/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0260 - val_loss: 0.0994 - lr: 0.0010
# Epoch 14/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0259 - val_loss: 0.0988 - lr: 0.0010
# Epoch 15/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0255 - val_loss: 0.0942 - lr: 0.0010
# Epoch 16/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0256 - val_loss: 0.0953 - lr: 0.0010
# Epoch 17/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0240 - val_loss: 0.0915 - lr: 0.0010
# Epoch 18/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0235 - val_loss: 0.0927 - lr: 0.0010
# Epoch 19/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0231 - val_loss: 0.0884 - lr: 0.0010
# Epoch 20/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0229 - val_loss: 0.0869 - lr: 0.0010
# Epoch 21/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0224 - val_loss: 0.0843 - lr: 0.0010
# Epoch 22/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0217 - val_loss: 0.0828 - lr: 0.0010
# Epoch 23/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0213 - val_loss: 0.0813 - lr: 0.0010
# Epoch 24/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0208 - val_loss: 0.0798 - lr: 0.0010
# Epoch 25/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0202 - val_loss: 0.0757 - lr: 0.0010
# Epoch 26/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0201 - val_loss: 0.0760 - lr: 0.0010
# Epoch 27/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0195 - val_loss: 0.0732 - lr: 0.0010
# Epoch 28/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0189 - val_loss: 0.0713 - lr: 0.0010
# Epoch 29/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0185 - val_loss: 0.0684 - lr: 0.0010
# Epoch 30/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0181 - val_loss: 0.0676 - lr: 0.0010
# Epoch 31/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0176 - val_loss: 0.0653 - lr: 0.0010
# Epoch 32/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0172 - val_loss: 0.0624 - lr: 0.0010
# Epoch 33/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0168 - val_loss: 0.0621 - lr: 0.0010
# Epoch 34/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0162 - val_loss: 0.0567 - lr: 0.0010
# Epoch 35/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0169 - val_loss: 0.0620 - lr: 0.0010
# Epoch 36/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0516 - lr: 0.0010
# Epoch 37/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0157 - val_loss: 0.0539 - lr: 0.0010
# Epoch 38/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0151 - val_loss: 0.0530 - lr: 0.0010
# Epoch 39/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0143 - val_loss: 0.0463 - lr: 0.0010
# Epoch 40/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0499 - lr: 0.0010
# Epoch 41/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0468 - lr: 0.0010
# Epoch 42/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0423 - lr: 0.0010
# Epoch 43/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0439 - lr: 0.0010
# Epoch 44/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0116 - val_loss: 0.0380 - lr: 0.0010
# Epoch 45/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0374 - lr: 0.0010
# Epoch 46/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0107 - val_loss: 0.0365 - lr: 0.0010
# Epoch 47/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0348 - lr: 0.0010
# Epoch 48/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0326 - lr: 0.0010
# Epoch 49/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0318 - lr: 0.0010
# Epoch 50/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0285 - lr: 0.0010
# Epoch 51/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0254 - lr: 0.0010
# Epoch 52/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0245 - lr: 0.0010
# Epoch 53/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.0226 - lr: 0.0010
# Epoch 54/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0081 - val_loss: 0.0205 - lr: 0.0010
# Epoch 55/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0189 - lr: 0.0010
# Epoch 56/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0184 - lr: 0.0010
# Epoch 57/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0159 - lr: 0.0010
# Epoch 58/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0142 - lr: 0.0010
# Epoch 59/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0116 - lr: 0.0010
# Epoch 60/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0115 - lr: 0.0010
# Epoch 61/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0109 - lr: 0.0010
# Epoch 62/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0104 - lr: 0.0010
# Epoch 63/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0111 - lr: 0.0010
# Epoch 64/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0111 - lr: 0.0010
# Epoch 65/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0123 - lr: 0.0010
# Epoch 66/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0121 - lr: 0.0010
# Epoch 67/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0131 - lr: 0.0010
# Epoch 68/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0129 - lr: 0.0010
# Epoch 69/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0154 - lr: 0.0010
# Epoch 70/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0119 - lr: 0.0010
# Epoch 71/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0121 - lr: 0.0010
# Epoch 72/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0140 - lr: 0.0010
# Epoch 73/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0163 - lr: 0.0010
# Epoch 74/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0145 - lr: 0.0010
# Epoch 75/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0149 - lr: 0.0010
# Epoch 76/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0132 - lr: 0.0010
# Epoch 77/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0159 - lr: 0.0010
# Epoch 78/200
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0054Backtracking to best model before reducting LR
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0142 - lr: 0.0010
# Epoch 79/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0105 - lr: 5.0000e-04
# Epoch 80/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0106 - lr: 5.0000e-04
# Epoch 81/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0113 - lr: 5.0000e-04
# Epoch 82/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0111 - lr: 5.0000e-04
# Epoch 83/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0118 - lr: 5.0000e-04
# Epoch 84/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0117 - lr: 5.0000e-04
# Epoch 85/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0121 - lr: 5.0000e-04
# Epoch 86/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0125 - lr: 5.0000e-04
# Epoch 87/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0132 - lr: 5.0000e-04
# Epoch 88/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0129 - lr: 5.0000e-04
# Epoch 89/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0127 - lr: 5.0000e-04
# Epoch 90/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0127 - lr: 5.0000e-04
# Epoch 91/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0130 - lr: 5.0000e-04
# Epoch 92/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0122 - lr: 5.0000e-04
# Epoch 93/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0130 - lr: 5.0000e-04
# Epoch 94/200
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0032Backtracking to best model before reducting LR
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0141 - lr: 5.0000e-04
# Epoch 95/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0107 - lr: 2.5000e-04
# Epoch 96/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0111 - lr: 2.5000e-04
# Epoch 97/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0107 - lr: 2.5000e-04
# Epoch 98/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0108 - lr: 2.5000e-04
# Epoch 99/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0113 - lr: 2.5000e-04
# Epoch 100/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0115 - lr: 2.5000e-04
# Epoch 101/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0109 - lr: 2.5000e-04
# Epoch 102/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0112 - lr: 2.5000e-04
# Epoch 103/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0113 - lr: 2.5000e-04
# Epoch 104/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0113 - lr: 2.5000e-04
# Epoch 105/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0113 - lr: 2.5000e-04
# Epoch 106/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0113 - lr: 2.5000e-04
# Epoch 107/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0119 - lr: 2.5000e-04
# Epoch 108/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0122 - lr: 2.5000e-04
# Epoch 109/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0122 - lr: 2.5000e-04
# Epoch 110/200
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0041Backtracking to best model before reducting LR
#
# Epoch 110: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0123 - lr: 2.5000e-04
# Epoch 111/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0113 - lr: 1.2500e-04
# Epoch 112/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0106 - lr: 1.2500e-04
# Epoch 113/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0110 - lr: 1.2500e-04
# Epoch 114/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0109 - lr: 1.2500e-04
# Epoch 115/200
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0046Restoring model weights from the end of the best epoch: 79.
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0109 - lr: 1.2500e-04
# Epoch 115: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Loss de treinamento')
plt.plot(history.history['val_loss'], label='Loss de validação')
plt.legend()
plt.savefig(f'{NOTEBOOK_NAME}/loss_sgd.png')

# %% [markdown]
# ## Resultados obtidos
#
# Comparando predições para as sequências separadas para teste

# %% [markdown]
# Dados de treinamento: primeiro a rede precisa ser capaz de apresentar um desempenho satisfatório para os dados que foram utilizados em seu treinamento...

# %%
predictions = model.predict(inputs_train)
if NORMALIZE:
    predictions = inlet_discharge_scaler.inverse_transform(predictions)
    temp = inlet_discharge_scaler.inverse_transform(outputs_train)
else:
    temp = outputs_train

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(temp, label='Dados de treinamento')
ax[0].plot(predictions, label='Predição')
ax[0].legend()
ax[0].set_title('Treinamento')

# zoom

ax[1].plot(temp[:200], label='Dados de treinamento')
ax[1].plot(predictions[:200], label='Predição')
ax[1].legend()
ax[1].set_title('Treinamento (primeiros 200)')
plt.savefig(f'{NOTEBOOK_NAME}/train_sgd.png')
# Out:
# 9/9 [==============================] - 0s 1ms/step

# %% [markdown]
# Dados de teste: agora é a hora da verdade.

# %%
predictions = model.predict(inputs_test)
if NORMALIZE:
    predictions = inlet_discharge_scaler.inverse_transform(predictions)
    temp = inlet_discharge_scaler.inverse_transform(outputs_test)
else:
    temp = outputs_test

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(temp, label='Dados de teste')
ax[0].plot(predictions, label='Predição')
ax[0].legend()
ax[0].set_title('Teste')

# zoom

ax[1].plot(temp[:200], label='Dados de teste')
ax[1].plot(predictions[:200], label='Predição')
ax[1].legend()
ax[1].set_title('Teste (primeiros 200)')
plt.savefig(f'{NOTEBOOK_NAME}/test_sgd.png')
# Out:
# 5/5 [==============================] - 0s 2ms/step
