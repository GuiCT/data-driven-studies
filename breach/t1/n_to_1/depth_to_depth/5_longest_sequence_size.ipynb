# %% [markdown]
# **Constantes**
#
# Tamanho da sequência utilizada, tamanho da janela, frequência de _cutoff_, tamanho de lote, etc.

# %%
BASE_VALUE = 'depth'
BATCH_SIZE = 32
CUTOFF_FREQUENCY = 0.009
DATA_FOLDER = '../../data'
DENSE_ACTIVATION_FUNCTION = 'linear'
EARLY_STOP_EPOCH = 66
EARLY_STOP_PATIENCE = 36
EPOCHS = 200
INITIAL_LEARNING_RATE = 0.001
LEARNING_RATE_REDUCER_FACTOR = 0.5
LEARNING_RATE_REDUCER_PATIENCE = 16
LSTM_COUNT = [8]
NORMALIZE = True
NOTEBOOK_NAME = '5_longest_sequence_size'
PREDICTED_VALUE = 'depth'
SAMPLE_RATE = 1
SEQUENCE_GAP = 25
SEQUENCE_SIZE = 50
TEST_SPLIT_FACTOR = 3

# %%
PLOT_TITLE = f'{BASE_VALUE} -> {PREDICTED_VALUE}'

# %%
from keras.callbacks import ReduceLROnPlateau
from tensorflow.python.platform import tf_logging as logging


class ReduceLRBacktrack(ReduceLROnPlateau):
    def __init__(self, best_path, *args, **kwargs):
        super(ReduceLRBacktrack, self).__init__(*args, **kwargs)
        self.best_path = best_path

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.monitor)
        if current is None:
            logging.warning('Reduce LR on plateau conditioned on metric `%s` '
                            'which is not available. Available metrics are: %s',
                            self.monitor, ','.join(list(logs.keys())))
        if not self.monitor_op(current, self.best):  # not new best
            if not self.in_cooldown():  # and we're not in cooldown
                if self.wait+1 >= self.patience:  # going to reduce lr
                    # load best model so far
                    print("Backtracking to best model before reducting LR")
                    self.model.load_weights(self.best_path)

        super().on_epoch_end(epoch, logs)  # actually reduce LR
# Out:
# 2023-10-27 16:28:08.425973: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-27 16:28:08.455229: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 16:28:08.455254: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 16:28:08.455271: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-27 16:28:08.460248: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-27 16:28:08.460807: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-27 16:28:09.348721: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Estado para reproduzir os mesmos resultados

# %%
from keras.utils import set_random_seed

set_random_seed(42)

# %% [markdown]
# # Preparação dos dados
#
# Carregando os arquivos .csv que contém os dados de altura da lâmina e vazão.

# %% [markdown]
# ## Altura

# %%
import pandas as pd

# %%
depth_df = pd.read_csv(f'{DATA_FOLDER}/water_depth_reservoir_Test1.csv')
display(depth_df)
# Out:
#       time (s)  water depth (m)  Unnamed: 2
# 0            0          0.45045         NaN
# 1            1          0.45070         NaN
# 2            2          0.45086         NaN
# 3            3          0.45096         NaN
# 4            4          0.45100         NaN
# ...        ...              ...         ...
# 4313      4313          0.43703         NaN
# 4314      4314          0.43711         NaN
# 4315      4315          0.43720         NaN
# 4316      4316          0.43729         NaN
# 4317      4317          0.43737         NaN
#
# [4318 rows x 3 columns]

# %% [markdown]
# Devido à forma como o CSV está organizado, há uma coluna extra indesejada.
#
# Para corrigir isso, podemos dropar essa coluna utilizando pandas.

# %%
depth_df = depth_df.drop(columns=[depth_df.columns[-1]])
display(depth_df)
# Out:
#       time (s)  water depth (m)
# 0            0          0.45045
# 1            1          0.45070
# 2            2          0.45086
# 3            3          0.45096
# 4            4          0.45100
# ...        ...              ...
# 4313      4313          0.43703
# 4314      4314          0.43711
# 4315      4315          0.43720
# 4316      4316          0.43729
# 4317      4317          0.43737
#
# [4318 rows x 2 columns]

# %% [markdown]
# Ignorando coluna com o valor do tempo, pois a coluna de índice é equivalente.

# %%
depth_df = depth_df.drop(columns=[depth_df.columns[0]])
display(depth_df)
# Out:
#       water depth (m)
# 0             0.45045
# 1             0.45070
# 2             0.45086
# 3             0.45096
# 4             0.45100
# ...               ...
# 4313          0.43703
# 4314          0.43711
# 4315          0.43720
# 4316          0.43729
# 4317          0.43737
#
# [4318 rows x 1 columns]

# %% [markdown]
# ## Vazão

# %%
discharge_df = pd.read_csv(f'{DATA_FOLDER}/discharge_inlet_Test1.csv')
display(discharge_df)
# Out:
#       time (s)  inlet discharge (m3/s)
# 0            1                0.000630
# 1            1                0.000388
# 2            1                0.000203
# 3            1                0.000070
# 4            4               -0.000020
# ...        ...                     ...
# 4313      4313                0.024713
# 4314      4314                0.024809
# 4315      4315                0.024889
# 4316      4316                0.024951
# 4317      4317                0.024999
#
# [4318 rows x 2 columns]

# %% [markdown]
# Na coluna indicando o tempo em segundos, o valor "1" está sendo repetido 4 vezes.
#
# Tendo em vista que os valores da vazão mudaram para essas 4 entradas, vamos assumir que isso foi um erro de registro e que os valores são na realidade 0, 1, 2, ...
#
# Essa mudança torna esse dataset consistente com o de altura carregado anteriormente.
#
# Da mesma forma como fizemos anteriormente, podemos tratar a coluna de índices como nosso indicador de tempo.

# %%
discharge_df = discharge_df.drop(columns=[discharge_df.columns[0]])
display(discharge_df)
# Out:
#       inlet discharge (m3/s)
# 0                   0.000630
# 1                   0.000388
# 2                   0.000203
# 3                   0.000070
# 4                  -0.000020
# ...                      ...
# 4313                0.024713
# 4314                0.024809
# 4315                0.024889
# 4316                0.024951
# 4317                0.024999
#
# [4318 rows x 1 columns]

# %% [markdown]
# Podemos unir os dados em um só DF, o que facilita a preparação dos mesmos

# %%
unified_df = pd.concat([discharge_df, depth_df], axis=1)
display(unified_df)
# Out:
#       inlet discharge (m3/s)  water depth (m)
# 0                   0.000630          0.45045
# 1                   0.000388          0.45070
# 2                   0.000203          0.45086
# 3                   0.000070          0.45096
# 4                  -0.000020          0.45100
# ...                      ...              ...
# 4313                0.024713          0.43703
# 4314                0.024809          0.43711
# 4315                0.024889          0.43720
# 4316                0.024951          0.43729
# 4317                0.024999          0.43737
#
# [4318 rows x 2 columns]

# %% [markdown]
# ## Remoção de ruídos

# %%
from scipy.signal import butter, filtfilt

smoothed_df = unified_df.copy()

original_discharge = smoothed_df['inlet discharge (m3/s)'].values
b, a = butter(N=6, Wn=CUTOFF_FREQUENCY/(0.5*SAMPLE_RATE), btype='low')
y = filtfilt(b, a, original_discharge)
smoothed_df['inlet discharge (m3/s)'] = y

original_depth = smoothed_df['water depth (m)'].values
b, a = butter(N=6, Wn=CUTOFF_FREQUENCY/(0.5*SAMPLE_RATE), btype='low')
y = filtfilt(b, a, original_depth)
smoothed_df['water depth (m)'] = y

# %% [markdown]
# Verificando resultado da remoção de ruído

# %%
import matplotlib.pyplot as plt

plt.plot(unified_df['inlet discharge (m3/s)'])
plt.plot(smoothed_df['inlet discharge (m3/s)'])
plt.show()

plt.plot(unified_df['inlet discharge (m3/s)'].values[:2000])
plt.plot(smoothed_df['inlet discharge (m3/s)'].values[:2000])
plt.show()

plt.plot(unified_df['water depth (m)'])
plt.plot(smoothed_df['water depth (m)'])
plt.show()

plt.plot(unified_df['water depth (m)'].values[:2000])
plt.plot(smoothed_df['water depth (m)'].values[:2000])
plt.show()

# %% [markdown]
# Convertendo o DataFrame em array numpy para facilitar acesso.

# %%
unified = smoothed_df.to_numpy()

# %% [markdown]
# ## Normalização

# %%
from sklearn.preprocessing import MinMaxScaler

unified_scaler = MinMaxScaler()
water_depth_scaler = MinMaxScaler()
inlet_discharge_scaler = MinMaxScaler()
water_depth_scaler.fit(unified[:, 1].reshape(-1, 1))
inlet_discharge_scaler.fit(unified[:, 0].reshape(-1, 1))
unified_scaler.fit(unified)
# Out:
# MinMaxScaler()

# %%
if NORMALIZE:
    if PREDICTED_VALUE == 'depth':
        OUTPUT_SCALER = water_depth_scaler
    elif PREDICTED_VALUE == 'discharge':
        OUTPUT_SCALER = inlet_discharge_scaler
    elif PREDICTED_VALUE == 'both':
        OUTPUT_SCALER = unified_scaler
    else:
        raise ValueError(f'PREDICTED_VALUE must be one of [depth, discharge, both], got {PREDICTED_VALUE}')
    unified = unified_scaler.transform(unified)

# %% [markdown]
# ## Estrutura dos dados de treinamento

# %%
# Obtendo índices lower..upper
i = 0
lower = list()
upper = list()
while i + SEQUENCE_SIZE < len(unified):
    lower.append(i)
    upper.append(i + SEQUENCE_SIZE)
    print(f"[{i}, {i + SEQUENCE_SIZE})")
    i += SEQUENCE_GAP
# Out:
# [0, 50)
# [25, 75)
# [50, 100)
# [75, 125)
# [100, 150)
# [125, 175)
# [150, 200)
# [175, 225)
# [200, 250)
# [225, 275)
# [250, 300)
# [275, 325)
# [300, 350)
# [325, 375)
# [350, 400)
# [375, 425)
# [400, 450)
# [425, 475)
# [450, 500)
# [475, 525)
# [500, 550)
# [525, 575)
# [550, 600)
# [575, 625)
# [600, 650)
# [625, 675)
# [650, 700)
# [675, 725)
# [700, 750)
# [725, 775)
# [750, 800)
# [775, 825)
# [800, 850)
# [825, 875)
# [850, 900)
# [875, 925)
# [900, 950)
# [925, 975)
# [950, 1000)
# [975, 1025)
# [1000, 1050)
# [1025, 1075)
# [1050, 1100)
# [1075, 1125)
# [1100, 1150)
# [1125, 1175)
# [1150, 1200)
# [1175, 1225)
# [1200, 1250)
# [1225, 1275)
# [1250, 1300)
# [1275, 1325)
# [1300, 1350)
# [1325, 1375)
# [1350, 1400)
# [1375, 1425)
# [1400, 1450)
# [1425, 1475)
# [1450, 1500)
# [1475, 1525)
# [1500, 1550)
# [1525, 1575)
# [1550, 1600)
# [1575, 1625)
# [1600, 1650)
# [1625, 1675)
# [1650, 1700)
# [1675, 1725)
# [1700, 1750)
# [1725, 1775)
# [1750, 1800)
# [1775, 1825)
# [1800, 1850)
# [1825, 1875)
# [1850, 1900)
# [1875, 1925)
# [1900, 1950)
# [1925, 1975)
# [1950, 2000)
# [1975, 2025)
# [2000, 2050)
# [2025, 2075)
# [2050, 2100)
# [2075, 2125)
# [2100, 2150)
# [2125, 2175)
# [2150, 2200)
# [2175, 2225)
# [2200, 2250)
# [2225, 2275)
# [2250, 2300)
# [2275, 2325)
# [2300, 2350)
# [2325, 2375)
# [2350, 2400)
# [2375, 2425)
# [2400, 2450)
# [2425, 2475)
# [2450, 2500)
# [2475, 2525)
# [2500, 2550)
# [2525, 2575)
# [2550, 2600)
# [2575, 2625)
# [2600, 2650)
# [2625, 2675)
# [2650, 2700)
# [2675, 2725)
# [2700, 2750)
# [2725, 2775)
# [2750, 2800)
# [2775, 2825)
# [2800, 2850)
# [2825, 2875)
# [2850, 2900)
# [2875, 2925)
# [2900, 2950)
# [2925, 2975)
# [2950, 3000)
# [2975, 3025)
# [3000, 3050)
# [3025, 3075)
# [3050, 3100)
# [3075, 3125)
# [3100, 3150)
# [3125, 3175)
# [3150, 3200)
# [3175, 3225)
# [3200, 3250)
# [3225, 3275)
# [3250, 3300)
# [3275, 3325)
# [3300, 3350)
# [3325, 3375)
# [3350, 3400)
# [3375, 3425)
# [3400, 3450)
# [3425, 3475)
# [3450, 3500)
# [3475, 3525)
# [3500, 3550)
# [3525, 3575)
# [3550, 3600)
# [3575, 3625)
# [3600, 3650)
# [3625, 3675)
# [3650, 3700)
# [3675, 3725)
# [3700, 3750)
# [3725, 3775)
# [3750, 3800)
# [3775, 3825)
# [3800, 3850)
# [3825, 3875)
# [3850, 3900)
# [3875, 3925)
# [3900, 3950)
# [3925, 3975)
# [3950, 4000)
# [3975, 4025)
# [4000, 4050)
# [4025, 4075)
# [4050, 4100)
# [4075, 4125)
# [4100, 4150)
# [4125, 4175)
# [4150, 4200)
# [4175, 4225)
# [4200, 4250)
# [4225, 4275)
# [4250, 4300)

# %% [markdown]
# Construindo sequência de inputs e outputs utilizadas pela rede.
#
# No caso desse notebook:
#
# - Input: Altura da lâmina
# - Output: Altura da lâmina

# %%
import numpy as np

number_of_sequences = len(lower)
display("Quantidade de sequências", number_of_sequences)

TRAINING_SIZE = int(number_of_sequences * (1 - 1 / TEST_SPLIT_FACTOR))
display("Quantidade de sequências de treinamento", TRAINING_SIZE)

inputs = np.zeros((number_of_sequences, SEQUENCE_SIZE, 1))
if PREDICTED_VALUE == 'both':
    outputs = np.zeros((number_of_sequences, SEQUENCE_SIZE, 2))
elif PREDICTED_VALUE == 'depth' or PREDICTED_VALUE == 'discharge':
    outputs = np.zeros((number_of_sequences, 1))
else:
    raise ValueError(f'PREDICTED_VALUE must be one of [depth, discharge, both], got {PREDICTED_VALUE}')
for i in range(number_of_sequences):
    if BASE_VALUE == 'depth':
        inputs[i, :] = unified[lower[i]:upper[i], 1].reshape(-1, 1)
    elif BASE_VALUE == 'discharge':
        inputs[i, :] = unified[lower[i]:upper[i], 0].reshape(-1, 1)
    elif BASE_VALUE == 'both':
        inputs[i, :] = unified[lower[i]:upper[i], :]
    else:
        raise ValueError(f'BASE_VALUE must be one of [depth, discharge, both], got {BASE_VALUE}')
    if PREDICTED_VALUE == 'both':
        outputs[i, :] = unified[upper[i], :]
    elif PREDICTED_VALUE == 'depth':
        outputs[i, :] = unified[upper[i], 1]
    elif PREDICTED_VALUE == 'discharge':
        outputs[i, :] = unified[upper[i], 0]
    else:
        raise ValueError(f'PREDICTED_VALUE must be one of [depth, discharge, both], got {PREDICTED_VALUE}')

inputs_train = inputs[:TRAINING_SIZE]
outputs_train = outputs[:TRAINING_SIZE]
inputs_test = inputs[TRAINING_SIZE:]
outputs_test = outputs[TRAINING_SIZE:]
display("Shapes", inputs_train.shape, outputs_train.shape,
        inputs_test.shape, outputs_test.shape)
# Out:
# 'Quantidade de sequências'
# 171
# 'Quantidade de sequências de treinamento'
# 114
# 'Shapes'
# (114, 50, 1)
# (114, 1)
# (57, 50, 1)
# (57, 1)

# %% [markdown]
# # Rede neural e treinamento (Adam)

# %%
from keras.models import Sequential
from keras.layers import LSTM, InputLayer, Dense
from keras.optimizers import Adam
from keras.utils import plot_model
import os

if os.path.exists(f'{NOTEBOOK_NAME}/model.png'):
    os.remove(f'{NOTEBOOK_NAME}/model.png')

model = Sequential(name=NOTEBOOK_NAME)
model.add(InputLayer(input_shape=((None, 1)), name='input_layer'))
for i, cell in enumerate(LSTM_COUNT[:-1]):
    model.add(LSTM(cell, return_sequences=True, name=f'lstm_layer_{i + 1}'))
model.add(LSTM(LSTM_COUNT[-1], name=f'lstm_layer_{len(LSTM_COUNT)}'))
model.add(Dense(1, DENSE_ACTIVATION_FUNCTION, name=DENSE_ACTIVATION_FUNCTION))
model.summary()
opt = Adam(learning_rate=INITIAL_LEARNING_RATE, amsgrad=True)

if not os.path.exists(NOTEBOOK_NAME):
    os.mkdir(NOTEBOOK_NAME)
plot_model(model, f'{NOTEBOOK_NAME}/model.png', show_shapes=True)
model.compile(loss='mae', optimizer=opt)
# Out:
# Model: "5_longest_sequence_size"
# 2023-10-27 16:28:11.447896: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-27 16:28:11.448313: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_layer_1 (LSTM)         (None, 8)                 320
#
#  linear (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 329 (1.29 KB)
# Trainable params: 329 (1.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

history = model.fit(
    inputs_train, outputs_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    shuffle=True,
    validation_batch_size=BATCH_SIZE//2,
    validation_split=0.15,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=EARLY_STOP_PATIENCE,
                      verbose=1, restore_best_weights=True, start_from_epoch=EARLY_STOP_EPOCH),
        ModelCheckpoint(f'{NOTEBOOK_NAME}/model_adam.h5',
                        save_best_only=True, save_weights_only=True),
        ReduceLRBacktrack(f'{NOTEBOOK_NAME}/model_adam.h5',
                          monitor='val_loss', patience=LEARNING_RATE_REDUCER_PATIENCE, factor=LEARNING_RATE_REDUCER_FACTOR, verbose=1)
    ]
)
# Recuperando melhor modelo
model.load_weights(f'{NOTEBOOK_NAME}/model_adam.h5')
# Out:
# Epoch 1/200
# 3/3 [==============================] - 2s 200ms/step - loss: 0.6366 - val_loss: 0.4613 - lr: 0.0010
# Epoch 2/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5937 - val_loss: 0.4227 - lr: 0.0010
# Epoch 3/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5506 - val_loss: 0.3840 - lr: 0.0010
# Epoch 4/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5074 - val_loss: 0.3451 - lr: 0.0010
# Epoch 5/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4643 - val_loss: 0.3061 - lr: 0.0010
# Epoch 6/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4214 - val_loss: 0.2670 - lr: 0.0010
# Epoch 7/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3783 - val_loss: 0.2276 - lr: 0.0010
# Epoch 8/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3353 - val_loss: 0.1878 - lr: 0.0010
# Epoch 9/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2919 - val_loss: 0.1499 - lr: 0.0010
# Epoch 10/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2481 - val_loss: 0.1281 - lr: 0.0010
# Epoch 11/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2036 - val_loss: 0.1235 - lr: 0.0010
# Epoch 12/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1580 - val_loss: 0.1207 - lr: 0.0010
# Epoch 13/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1113 - val_loss: 0.1181 - lr: 0.0010
# Epoch 14/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0693 - val_loss: 0.1285 - lr: 0.0010
# Epoch 15/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0410 - val_loss: 0.1477 - lr: 0.0010
# Epoch 16/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0434 - val_loss: 0.1630 - lr: 0.0010
# Epoch 17/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0580 - val_loss: 0.1669 - lr: 0.0010
# Epoch 18/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0594 - val_loss: 0.1616 - lr: 0.0010
# Epoch 19/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0498 - val_loss: 0.1511 - lr: 0.0010
# Epoch 20/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0380 - val_loss: 0.1402 - lr: 0.0010
# Epoch 21/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0382 - val_loss: 0.1332 - lr: 0.0010
# Epoch 22/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0398 - val_loss: 0.1304 - lr: 0.0010
# Epoch 23/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0408 - val_loss: 0.1302 - lr: 0.0010
# Epoch 24/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0396 - val_loss: 0.1327 - lr: 0.0010
# Epoch 25/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0368 - val_loss: 0.1355 - lr: 0.0010
# Epoch 26/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0360 - val_loss: 0.1389 - lr: 0.0010
# Epoch 27/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0362 - val_loss: 0.1406 - lr: 0.0010
# Epoch 28/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0363 - val_loss: 0.1393 - lr: 0.0010
# Epoch 29/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0293Backtracking to best model before reducting LR
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0357 - val_loss: 0.1363 - lr: 0.0010
# Epoch 30/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0815 - val_loss: 0.1178 - lr: 5.0000e-04
# Epoch 31/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0768 - val_loss: 0.1188 - lr: 5.0000e-04
# Epoch 32/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0672 - val_loss: 0.1211 - lr: 5.0000e-04
# Epoch 33/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0559 - val_loss: 0.1263 - lr: 5.0000e-04
# Epoch 34/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0452 - val_loss: 0.1331 - lr: 5.0000e-04
# Epoch 35/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0389 - val_loss: 0.1399 - lr: 5.0000e-04
# Epoch 36/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0368 - val_loss: 0.1464 - lr: 5.0000e-04
# Epoch 37/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0391 - val_loss: 0.1500 - lr: 5.0000e-04
# Epoch 38/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0411 - val_loss: 0.1497 - lr: 5.0000e-04
# Epoch 39/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0401 - val_loss: 0.1465 - lr: 5.0000e-04
# Epoch 40/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0378 - val_loss: 0.1422 - lr: 5.0000e-04
# Epoch 41/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0364 - val_loss: 0.1382 - lr: 5.0000e-04
# Epoch 42/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0365 - val_loss: 0.1351 - lr: 5.0000e-04
# Epoch 43/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0364 - val_loss: 0.1337 - lr: 5.0000e-04
# Epoch 44/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0367 - val_loss: 0.1330 - lr: 5.0000e-04
# Epoch 45/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0365 - val_loss: 0.1332 - lr: 5.0000e-04
# Epoch 46/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0391Backtracking to best model before reducting LR
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0362 - val_loss: 0.1338 - lr: 5.0000e-04
# Epoch 47/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0783 - val_loss: 0.1179 - lr: 2.5000e-04
# Epoch 48/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0744 - val_loss: 0.1189 - lr: 2.5000e-04
# Epoch 49/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0681 - val_loss: 0.1203 - lr: 2.5000e-04
# Epoch 50/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0606 - val_loss: 0.1227 - lr: 2.5000e-04
# Epoch 51/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0534 - val_loss: 0.1264 - lr: 2.5000e-04
# Epoch 52/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0469 - val_loss: 0.1306 - lr: 2.5000e-04
# Epoch 53/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0423 - val_loss: 0.1348 - lr: 2.5000e-04
# Epoch 54/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0383 - val_loss: 0.1384 - lr: 2.5000e-04
# Epoch 55/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0370 - val_loss: 0.1419 - lr: 2.5000e-04
# Epoch 56/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0368 - val_loss: 0.1446 - lr: 2.5000e-04
# Epoch 57/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0377 - val_loss: 0.1462 - lr: 2.5000e-04
# Epoch 58/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0382 - val_loss: 0.1466 - lr: 2.5000e-04
# Epoch 59/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0382 - val_loss: 0.1460 - lr: 2.5000e-04
# Epoch 60/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0378 - val_loss: 0.1446 - lr: 2.5000e-04
# Epoch 61/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0372 - val_loss: 0.1429 - lr: 2.5000e-04
# Epoch 62/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0256Backtracking to best model before reducting LR
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0366 - val_loss: 0.1409 - lr: 2.5000e-04
# Epoch 63/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0792 - val_loss: 0.1177 - lr: 1.2500e-04
# Epoch 64/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0784 - val_loss: 0.1178 - lr: 1.2500e-04
# Epoch 65/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0759 - val_loss: 0.1183 - lr: 1.2500e-04
# Epoch 66/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0724 - val_loss: 0.1191 - lr: 1.2500e-04
# Epoch 67/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0684 - val_loss: 0.1200 - lr: 1.2500e-04
# Epoch 68/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0638 - val_loss: 0.1210 - lr: 1.2500e-04
# Epoch 69/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0589 - val_loss: 0.1227 - lr: 1.2500e-04
# Epoch 70/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0544 - val_loss: 0.1245 - lr: 1.2500e-04
# Epoch 71/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0507 - val_loss: 0.1270 - lr: 1.2500e-04
# Epoch 72/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0471 - val_loss: 0.1294 - lr: 1.2500e-04
# Epoch 73/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0440 - val_loss: 0.1316 - lr: 1.2500e-04
# Epoch 74/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0418 - val_loss: 0.1337 - lr: 1.2500e-04
# Epoch 75/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0400 - val_loss: 0.1357 - lr: 1.2500e-04
# Epoch 76/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0385 - val_loss: 0.1374 - lr: 1.2500e-04
# Epoch 77/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0376 - val_loss: 0.1389 - lr: 1.2500e-04
# Epoch 78/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0417Backtracking to best model before reducting LR
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0370 - val_loss: 0.1403 - lr: 1.2500e-04
# Epoch 79/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0784 - val_loss: 0.1178 - lr: 6.2500e-05
# Epoch 80/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0766 - val_loss: 0.1180 - lr: 6.2500e-05
# Epoch 81/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0745 - val_loss: 0.1185 - lr: 6.2500e-05
# Epoch 82/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0722 - val_loss: 0.1190 - lr: 6.2500e-05
# Epoch 83/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0697 - val_loss: 0.1196 - lr: 6.2500e-05
# Epoch 84/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0670 - val_loss: 0.1202 - lr: 6.2500e-05
# Epoch 85/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0643 - val_loss: 0.1208 - lr: 6.2500e-05
# Epoch 86/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0617 - val_loss: 0.1214 - lr: 6.2500e-05
# Epoch 87/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0590 - val_loss: 0.1224 - lr: 6.2500e-05
# Epoch 88/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0567 - val_loss: 0.1234 - lr: 6.2500e-05
# Epoch 89/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0542 - val_loss: 0.1243 - lr: 6.2500e-05
# Epoch 90/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0520 - val_loss: 0.1255 - lr: 6.2500e-05
# Epoch 91/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0501 - val_loss: 0.1267 - lr: 6.2500e-05
# Epoch 92/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0484 - val_loss: 0.1279 - lr: 6.2500e-05
# Epoch 93/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0468 - val_loss: 0.1290 - lr: 6.2500e-05
# Epoch 94/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0479Backtracking to best model before reducting LR
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0455 - val_loss: 0.1302 - lr: 6.2500e-05
# Epoch 95/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0785 - val_loss: 0.1178 - lr: 3.1250e-05
# Epoch 96/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0773 - val_loss: 0.1179 - lr: 3.1250e-05
# Epoch 97/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0760 - val_loss: 0.1181 - lr: 3.1250e-05
# Epoch 98/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0746 - val_loss: 0.1184 - lr: 3.1250e-05
# Epoch 99/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0732 - val_loss: 0.1187 - lr: 3.1250e-05
# Epoch 100/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0717 - val_loss: 0.1190 - lr: 3.1250e-05
# Epoch 101/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0704 - val_loss: 0.1193 - lr: 3.1250e-05
# Epoch 102/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0690 - val_loss: 0.1197 - lr: 3.1250e-05
# Epoch 103/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0676 - val_loss: 0.1200 - lr: 3.1250e-05
# Epoch 104/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0662 - val_loss: 0.1203 - lr: 3.1250e-05
# Epoch 105/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0648 - val_loss: 0.1206 - lr: 3.1250e-05
# Epoch 106/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0634 - val_loss: 0.1209 - lr: 3.1250e-05
# Epoch 107/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0620 - val_loss: 0.1212 - lr: 3.1250e-05
# Epoch 108/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0607 - val_loss: 0.1215 - lr: 3.1250e-05
# Epoch 109/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0594 - val_loss: 0.1220 - lr: 3.1250e-05
# Epoch 110/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0539Backtracking to best model before reducting LR
#
# Epoch 110: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0582 - val_loss: 0.1225 - lr: 3.1250e-05
# Epoch 111/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 1.5625e-05
# Epoch 112/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0780 - val_loss: 0.1178 - lr: 1.5625e-05
# Epoch 113/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0773 - val_loss: 0.1179 - lr: 1.5625e-05
# Epoch 114/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0766 - val_loss: 0.1180 - lr: 1.5625e-05
# Epoch 115/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0758 - val_loss: 0.1181 - lr: 1.5625e-05
# Epoch 116/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0751 - val_loss: 0.1183 - lr: 1.5625e-05
# Epoch 117/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0744 - val_loss: 0.1184 - lr: 1.5625e-05
# Epoch 118/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0736 - val_loss: 0.1186 - lr: 1.5625e-05
# Epoch 119/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0729 - val_loss: 0.1187 - lr: 1.5625e-05
# Epoch 120/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0722 - val_loss: 0.1189 - lr: 1.5625e-05
# Epoch 121/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0715 - val_loss: 0.1190 - lr: 1.5625e-05
# Epoch 122/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0708 - val_loss: 0.1192 - lr: 1.5625e-05
# Epoch 123/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0702 - val_loss: 0.1194 - lr: 1.5625e-05
# Epoch 124/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0695 - val_loss: 0.1195 - lr: 1.5625e-05
# Epoch 125/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0687 - val_loss: 0.1197 - lr: 1.5625e-05
# Epoch 126/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0621Backtracking to best model before reducting LR
#
# Epoch 126: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0681 - val_loss: 0.1198 - lr: 1.5625e-05
# Epoch 127/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0788 - val_loss: 0.1178 - lr: 7.8125e-06
# Epoch 128/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0784 - val_loss: 0.1178 - lr: 7.8125e-06
# Epoch 129/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0781 - val_loss: 0.1178 - lr: 7.8125e-06
# Epoch 130/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0777 - val_loss: 0.1179 - lr: 7.8125e-06
# Epoch 131/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0774 - val_loss: 0.1179 - lr: 7.8125e-06
# Epoch 132/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0770 - val_loss: 0.1179 - lr: 7.8125e-06
# Epoch 133/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0766 - val_loss: 0.1179 - lr: 7.8125e-06
# Epoch 134/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0763 - val_loss: 0.1180 - lr: 7.8125e-06
# Epoch 135/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0759 - val_loss: 0.1180 - lr: 7.8125e-06
# Epoch 136/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0756 - val_loss: 0.1181 - lr: 7.8125e-06
# Epoch 137/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0752 - val_loss: 0.1182 - lr: 7.8125e-06
# Epoch 138/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0749 - val_loss: 0.1183 - lr: 7.8125e-06
# Epoch 139/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0745 - val_loss: 0.1183 - lr: 7.8125e-06
# Epoch 140/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0742 - val_loss: 0.1184 - lr: 7.8125e-06
# Epoch 141/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0738 - val_loss: 0.1185 - lr: 7.8125e-06
# Epoch 142/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0735Backtracking to best model before reducting LR
#
# Epoch 142: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0735 - val_loss: 0.1186 - lr: 7.8125e-06
# Epoch 143/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0789 - val_loss: 0.1178 - lr: 3.9063e-06
# Epoch 144/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 3.9063e-06
# Epoch 145/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0785 - val_loss: 0.1178 - lr: 3.9063e-06
# Epoch 146/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0783 - val_loss: 0.1178 - lr: 3.9063e-06
# Epoch 147/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0782 - val_loss: 0.1178 - lr: 3.9063e-06
# Epoch 148/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0780 - val_loss: 0.1178 - lr: 3.9063e-06
# Epoch 149/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0778 - val_loss: 0.1178 - lr: 3.9063e-06
# Epoch 150/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0776 - val_loss: 0.1179 - lr: 3.9063e-06
# Epoch 151/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0775 - val_loss: 0.1179 - lr: 3.9063e-06
# Epoch 152/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0773 - val_loss: 0.1179 - lr: 3.9063e-06
# Epoch 153/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0771 - val_loss: 0.1179 - lr: 3.9063e-06
# Epoch 154/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0769 - val_loss: 0.1179 - lr: 3.9063e-06
# Epoch 155/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0768 - val_loss: 0.1179 - lr: 3.9063e-06
# Epoch 156/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0766 - val_loss: 0.1179 - lr: 3.9063e-06
# Epoch 157/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0764 - val_loss: 0.1180 - lr: 3.9063e-06
# Epoch 158/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0915Backtracking to best model before reducting LR
#
# Epoch 158: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0762 - val_loss: 0.1180 - lr: 3.9063e-06
# Epoch 159/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0789 - val_loss: 0.1177 - lr: 1.9531e-06
# Epoch 160/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0788 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 161/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 162/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0786 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 163/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0785 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 164/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0785 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 165/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0784 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 166/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0783 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 167/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0782 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 168/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0781 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 169/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0780 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 170/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0779 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 171/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0779 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 172/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0778 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 173/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0777 - val_loss: 0.1178 - lr: 1.9531e-06
# Epoch 174/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0820Backtracking to best model before reducting LR
#
# Epoch 174: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0776 - val_loss: 0.1179 - lr: 1.9531e-06
# Epoch 175/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0789 - val_loss: 0.1177 - lr: 9.7656e-07
# Epoch 176/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0789 - val_loss: 0.1177 - lr: 9.7656e-07
# Epoch 177/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0788 - val_loss: 0.1177 - lr: 9.7656e-07
# Epoch 178/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0788 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 179/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 180/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 181/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 182/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0786 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 183/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0786 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 184/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0785 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 185/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0785 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 186/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0784 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 187/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0784 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 188/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0784 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 189/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0783 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 190/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0812Backtracking to best model before reducting LR
#
# Epoch 190: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0783 - val_loss: 0.1178 - lr: 9.7656e-07
# Epoch 191/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0789 - val_loss: 0.1177 - lr: 4.8828e-07
# Epoch 192/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0789 - val_loss: 0.1177 - lr: 4.8828e-07
# Epoch 193/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0789 - val_loss: 0.1177 - lr: 4.8828e-07
# Epoch 194/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0789 - val_loss: 0.1177 - lr: 4.8828e-07
# Epoch 195/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0788 - val_loss: 0.1177 - lr: 4.8828e-07
# Epoch 196/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0788 - val_loss: 0.1177 - lr: 4.8828e-07
# Epoch 197/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0788 - val_loss: 0.1177 - lr: 4.8828e-07
# Epoch 198/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0788 - val_loss: 0.1178 - lr: 4.8828e-07
# Epoch 199/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 4.8828e-07
# Epoch 200/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0787 - val_loss: 0.1178 - lr: 4.8828e-07

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Loss de treinamento')
plt.plot(history.history['val_loss'], label='Loss de validação')
plt.legend()
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title(f'Loss: {PLOT_TITLE}; Otimizador Adam')
plt.savefig(f'{NOTEBOOK_NAME}/loss_adam.png')

# %% [markdown]
# ## Resultados obtidos

# %%
predictions_train = model.predict(inputs_train)
predictions_test = model.predict(inputs_test)
if NORMALIZE:
    predictions_train = OUTPUT_SCALER.inverse_transform(predictions_train)
    predictions_test = OUTPUT_SCALER.inverse_transform(predictions_test)
    temp_train = OUTPUT_SCALER.inverse_transform(outputs_train)
    temp_test = OUTPUT_SCALER.inverse_transform(outputs_test)
else:
    temp_train = outputs_train
    temp_test = outputs_test

fig, ax = plt.subplots(1, 2, figsize=(12, 7))

ax[0].plot(temp_train, label='Dados reais')
ax[0].plot(predictions_train, label='Predição')
ax[0].legend()
ax[0].set_title('Treinamento')

ax[1].plot(temp_test, label='Dados reais')
ax[1].plot(predictions_test, label='Predição')
ax[1].legend()
ax[1].set_title('Teste')

fig.suptitle(f'Predições {PLOT_TITLE}, otimizador Adam')
plt.savefig(f'{NOTEBOOK_NAME}/predictions_adam.png')
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step

# %% [markdown]
# # Rede neural e treinamento (SGD)

# %%
from keras.models import Sequential
from keras.layers import LSTM, InputLayer, Dense
from keras.optimizers import SGD

model = Sequential(name=NOTEBOOK_NAME)
model.add(InputLayer(input_shape=((None, 1)), name='input_layer'))
for i, cell in enumerate(LSTM_COUNT[:-1]):
    model.add(LSTM(cell, return_sequences=True, name=f'lstm_layer_{i + 1}'))
model.add(LSTM(LSTM_COUNT[-1], name=f'lstm_layer_{len(LSTM_COUNT)}'))
model.add(Dense(1, DENSE_ACTIVATION_FUNCTION, name=DENSE_ACTIVATION_FUNCTION))
model.summary()
opt = SGD(learning_rate=INITIAL_LEARNING_RATE, momentum=0.9)
model.compile(loss='mae', optimizer=opt)
# Out:
# Model: "5_longest_sequence_size"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_layer_1 (LSTM)         (None, 8)                 320
#
#  linear (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 329 (1.29 KB)
# Trainable params: 329 (1.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

history = model.fit(
    inputs_train, outputs_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    shuffle=True,
    validation_batch_size=BATCH_SIZE//2,
    validation_split=0.15,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=EARLY_STOP_PATIENCE,
                      verbose=1, restore_best_weights=True, start_from_epoch=EARLY_STOP_EPOCH),
        ModelCheckpoint(f'{NOTEBOOK_NAME}/model_sgd.h5',
                        save_best_only=True, save_weights_only=True),
        ReduceLRBacktrack(f'{NOTEBOOK_NAME}/model_sgd.h5',
                          monitor='val_loss', patience=LEARNING_RATE_REDUCER_PATIENCE, factor=LEARNING_RATE_REDUCER_FACTOR, verbose=1)
    ]
)
# Recuperando melhor modelo
model.load_weights(f'{NOTEBOOK_NAME}/model_sgd.h5')
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 191ms/step - loss: 0.4330 - val_loss: 0.3217 - lr: 0.0010
# Epoch 2/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4032 - val_loss: 0.2780 - lr: 0.0010
# Epoch 3/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3510 - val_loss: 0.2165 - lr: 0.0010
# Epoch 4/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2821 - val_loss: 0.1419 - lr: 0.0010
# Epoch 5/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2010 - val_loss: 0.0945 - lr: 0.0010
# Epoch 6/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1108 - val_loss: 0.0934 - lr: 0.0010
# Epoch 7/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0337 - val_loss: 0.1314 - lr: 0.0010
# Epoch 8/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0625 - val_loss: 0.1663 - lr: 0.0010
# Epoch 9/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0919 - val_loss: 0.1704 - lr: 0.0010
# Epoch 10/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0850 - val_loss: 0.1486 - lr: 0.0010
# Epoch 11/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0540 - val_loss: 0.1206 - lr: 0.0010
# Epoch 12/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0303 - val_loss: 0.0996 - lr: 0.0010
# Epoch 13/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0438 - val_loss: 0.0949 - lr: 0.0010
# Epoch 14/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0497 - val_loss: 0.0968 - lr: 0.0010
# Epoch 15/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0386 - val_loss: 0.1066 - lr: 0.0010
# Epoch 16/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0297 - val_loss: 0.1197 - lr: 0.0010
# Epoch 17/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0337 - val_loss: 0.1221 - lr: 0.0010
# Epoch 18/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0325 - val_loss: 0.1139 - lr: 0.0010
# Epoch 19/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0286 - val_loss: 0.1064 - lr: 0.0010
# Epoch 20/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0291 - val_loss: 0.1047 - lr: 0.0010
# Epoch 21/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0292 - val_loss: 0.1060 - lr: 0.0010
# Epoch 22/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0327Backtracking to best model before reducting LR
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0277 - val_loss: 0.1099 - lr: 0.0010
# Epoch 23/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0478 - val_loss: 0.0966 - lr: 5.0000e-04
# Epoch 24/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0366 - val_loss: 0.1049 - lr: 5.0000e-04
# Epoch 25/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0284 - val_loss: 0.1138 - lr: 5.0000e-04
# Epoch 26/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0302 - val_loss: 0.1196 - lr: 5.0000e-04
# Epoch 27/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0340 - val_loss: 0.1190 - lr: 5.0000e-04
# Epoch 28/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0319 - val_loss: 0.1134 - lr: 5.0000e-04
# Epoch 29/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0278 - val_loss: 0.1073 - lr: 5.0000e-04
# Epoch 30/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0279 - val_loss: 0.1036 - lr: 5.0000e-04
# Epoch 31/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0290 - val_loss: 0.1025 - lr: 5.0000e-04
# Epoch 32/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0288 - val_loss: 0.1037 - lr: 5.0000e-04
# Epoch 33/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0278 - val_loss: 0.1058 - lr: 5.0000e-04
# Epoch 34/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0270 - val_loss: 0.1078 - lr: 5.0000e-04
# Epoch 35/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0272 - val_loss: 0.1092 - lr: 5.0000e-04
# Epoch 36/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0272 - val_loss: 0.1084 - lr: 5.0000e-04
# Epoch 37/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0269 - val_loss: 0.1066 - lr: 5.0000e-04
# Epoch 38/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0270Backtracking to best model before reducting LR
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0267 - val_loss: 0.1050 - lr: 5.0000e-04
# Epoch 39/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0516 - val_loss: 0.0935 - lr: 2.5000e-04
# Epoch 40/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0484 - val_loss: 0.0946 - lr: 2.5000e-04
# Epoch 41/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0420 - val_loss: 0.0979 - lr: 2.5000e-04
# Epoch 42/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0355 - val_loss: 0.1029 - lr: 2.5000e-04
# Epoch 43/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0305 - val_loss: 0.1078 - lr: 2.5000e-04
# Epoch 44/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0279 - val_loss: 0.1123 - lr: 2.5000e-04
# Epoch 45/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0283 - val_loss: 0.1151 - lr: 2.5000e-04
# Epoch 46/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0295 - val_loss: 0.1160 - lr: 2.5000e-04
# Epoch 47/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0296 - val_loss: 0.1148 - lr: 2.5000e-04
# Epoch 48/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0288 - val_loss: 0.1129 - lr: 2.5000e-04
# Epoch 49/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0279 - val_loss: 0.1107 - lr: 2.5000e-04
# Epoch 50/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0276 - val_loss: 0.1087 - lr: 2.5000e-04
# Epoch 51/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0276 - val_loss: 0.1073 - lr: 2.5000e-04
# Epoch 52/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0276 - val_loss: 0.1067 - lr: 2.5000e-04
# Epoch 53/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0276 - val_loss: 0.1066 - lr: 2.5000e-04
# Epoch 54/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0330Backtracking to best model before reducting LR
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0275 - val_loss: 0.1068 - lr: 2.5000e-04
# Epoch 55/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0511 - val_loss: 0.0939 - lr: 1.2500e-04
# Epoch 56/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0482 - val_loss: 0.0947 - lr: 1.2500e-04
# Epoch 57/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0439 - val_loss: 0.0965 - lr: 1.2500e-04
# Epoch 58/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0398 - val_loss: 0.0991 - lr: 1.2500e-04
# Epoch 59/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0354 - val_loss: 0.1019 - lr: 1.2500e-04
# Epoch 60/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0320 - val_loss: 0.1046 - lr: 1.2500e-04
# Epoch 61/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0300 - val_loss: 0.1071 - lr: 1.2500e-04
# Epoch 62/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0286 - val_loss: 0.1093 - lr: 1.2500e-04
# Epoch 63/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0280 - val_loss: 0.1113 - lr: 1.2500e-04
# Epoch 64/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0279 - val_loss: 0.1126 - lr: 1.2500e-04
# Epoch 65/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0280 - val_loss: 0.1133 - lr: 1.2500e-04
# Epoch 66/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0282 - val_loss: 0.1134 - lr: 1.2500e-04
# Epoch 67/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0282 - val_loss: 0.1131 - lr: 1.2500e-04
# Epoch 68/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0281 - val_loss: 0.1125 - lr: 1.2500e-04
# Epoch 69/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0279 - val_loss: 0.1117 - lr: 1.2500e-04
# Epoch 70/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0312Backtracking to best model before reducting LR
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0278 - val_loss: 0.1109 - lr: 1.2500e-04
# Epoch 71/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0518 - val_loss: 0.0934 - lr: 6.2500e-05
# Epoch 72/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0513 - val_loss: 0.0936 - lr: 6.2500e-05
# Epoch 73/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0498 - val_loss: 0.0941 - lr: 6.2500e-05
# Epoch 74/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0475 - val_loss: 0.0947 - lr: 6.2500e-05
# Epoch 75/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0450 - val_loss: 0.0956 - lr: 6.2500e-05
# Epoch 76/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0422 - val_loss: 0.0968 - lr: 6.2500e-05
# Epoch 77/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0394 - val_loss: 0.0983 - lr: 6.2500e-05
# Epoch 78/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0369 - val_loss: 0.1000 - lr: 6.2500e-05
# Epoch 79/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0349 - val_loss: 0.1016 - lr: 6.2500e-05
# Epoch 80/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0329 - val_loss: 0.1032 - lr: 6.2500e-05
# Epoch 81/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0313 - val_loss: 0.1046 - lr: 6.2500e-05
# Epoch 82/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0303 - val_loss: 0.1058 - lr: 6.2500e-05
# Epoch 83/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0294 - val_loss: 0.1070 - lr: 6.2500e-05
# Epoch 84/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0287 - val_loss: 0.1080 - lr: 6.2500e-05
# Epoch 85/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0284 - val_loss: 0.1089 - lr: 6.2500e-05
# Epoch 86/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0263Backtracking to best model before reducting LR
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0280 - val_loss: 0.1097 - lr: 6.2500e-05
# Epoch 87/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0512 - val_loss: 0.0937 - lr: 3.1250e-05
# Epoch 88/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0498 - val_loss: 0.0940 - lr: 3.1250e-05
# Epoch 89/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0481 - val_loss: 0.0944 - lr: 3.1250e-05
# Epoch 90/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0464 - val_loss: 0.0949 - lr: 3.1250e-05
# Epoch 91/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0446 - val_loss: 0.0955 - lr: 3.1250e-05
# Epoch 92/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0429 - val_loss: 0.0962 - lr: 3.1250e-05
# Epoch 93/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0412 - val_loss: 0.0969 - lr: 3.1250e-05
# Epoch 94/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0398 - val_loss: 0.0976 - lr: 3.1250e-05
# Epoch 95/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0384 - val_loss: 0.0985 - lr: 3.1250e-05
# Epoch 96/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0371 - val_loss: 0.0994 - lr: 3.1250e-05
# Epoch 97/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0360 - val_loss: 0.1002 - lr: 3.1250e-05
# Epoch 98/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0349 - val_loss: 0.1010 - lr: 3.1250e-05
# Epoch 99/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0340 - val_loss: 0.1018 - lr: 3.1250e-05
# Epoch 100/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0331 - val_loss: 0.1025 - lr: 3.1250e-05
# Epoch 101/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0322 - val_loss: 0.1032 - lr: 3.1250e-05
# Epoch 102/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0275Backtracking to best model before reducting LR
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0316 - val_loss: 0.1039 - lr: 3.1250e-05
# Epoch 103/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0512 - val_loss: 0.0937 - lr: 1.5625e-05
# Epoch 104/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0500 - val_loss: 0.0940 - lr: 1.5625e-05
# Epoch 105/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0489 - val_loss: 0.0942 - lr: 1.5625e-05
# Epoch 106/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0477 - val_loss: 0.0945 - lr: 1.5625e-05
# Epoch 107/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0481Restoring model weights from the end of the best epoch: 71.
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0466 - val_loss: 0.0947 - lr: 1.5625e-05
# Epoch 107: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Loss de treinamento')
plt.plot(history.history['val_loss'], label='Loss de validação')
plt.legend()
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title(f'Loss: {PLOT_TITLE}; Otimizador SGD')
plt.savefig(f'{NOTEBOOK_NAME}/loss_sgd.png')

# %% [markdown]
# ## Resultados obtidos
#
# Comparando predições para as sequências separadas para teste

# %% [markdown]
# Dados de treinamento: primeiro a rede precisa ser capaz de apresentar um desempenho satisfatório para os dados que foram utilizados em seu treinamento...

# %%
predictions_train = model.predict(inputs_train)
predictions_test = model.predict(inputs_test)
if NORMALIZE:
    predictions_train = OUTPUT_SCALER.inverse_transform(predictions_train)
    predictions_test = OUTPUT_SCALER.inverse_transform(predictions_test)
    temp_train = OUTPUT_SCALER.inverse_transform(outputs_train)
    temp_test = OUTPUT_SCALER.inverse_transform(outputs_test)
else:
    temp_train = outputs_train
    temp_test = outputs_test

fig, ax = plt.subplots(1, 2, figsize=(12, 7))

ax[0].plot(temp_train, label='Dados reais')
ax[0].plot(predictions_train, label='Predição')
ax[0].legend()
ax[0].set_title('Treinamento')

ax[1].plot(temp_test, label='Dados reais')
ax[1].plot(predictions_test, label='Predição')
ax[1].legend()
ax[1].set_title('Teste')

fig.suptitle(f'Predições {PLOT_TITLE}, otimizador SGD')
plt.savefig(f'{NOTEBOOK_NAME}/predictions_sgd.png')
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
